# %% [markdown]
# # Face Recognation
# Project based on: [Build a Deep Facial Recognition App](https://www.youtube.com/watch?v=bK_k7eebGgc&list=PLgNJO2hghbmhHuhURAGbe6KWpiYZt0AMH)

# %% [markdown]
# # 1. Set up and get data

# %% [markdown]
# # 1.1 Install dependencies

# %% [markdown]
# !pip install tensorflow

# %%
# !pip install labelme tensorflow opencv-python matplotlib albumentations
# Out:
# /bin/bash: pip: command not found

# %% [markdown]
# ## 1.2 Collect images using openCV

# %%
import os
import time
import uuid # for unique id
import cv2
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt
import albumentations as alb
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import load_model

# %%
IMAGES_PATH = os.path.join('data', 'images')
NUM_IMAGES_TO_COLLECT = 20

# %%
# Conection to video camera and get images
cap = cv2.VideoCapture(0) # if you are on winodws try 1 instead of 0
for imgnum in range(NUM_IMAGES_TO_COLLECT):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0xFF == ord('q'): # turn off the camera
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19

# %% [markdown]
# ## 1.3 Annotate images with labelMe

# %%
#/Users/asialalala/.local/pipx/venvs/labelme/bin/labelme
# !labelme
# Out:
# 2024-05-25 18:47:29,198 [INFO   ] __init__:get_config:67- Loading config file from: C:\Users\biuro\.labelmerc

# %% [markdown]
# # 2. Review Dataset and Build Image Loading Function

# %% [markdown]
# ## 2.1 Import packages

# %% [markdown]
# ## 2.2 Limit GPU Memory Growth

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
# WARNING!!!! It should be trye, but it is false

# %%
# check if tensorflow is available
tf.config.list_physical_devices('GPU')
#tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /var/folders/8v/3jz4k9_n36l7skpxnlc145240000gn/T/ipykernel_73664/637878255.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
images = tf.data.Dataset.list_files('data/images/*.jpg')

# %%
# variable 'images' contains path to images files
images.as_numpy_iterator().next()
# Out:
# b'data/images/8563edff-1aaf-11ef-aee3-bd5cfcf36af4.jpg'

# %%
# read images and load them as jpeg to img
def load_image(x): 
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next()
# Out:
# array([[[144, 149, 142],
#         [145, 150, 143],
#         [145, 151, 141],
#         ...,
#         [ 94, 109, 104],
#         [ 96, 109, 102],
#         [ 98, 111, 104]],
#
#        [[142, 147, 140],
#         [146, 151, 144],
#         [149, 154, 147],
#         ...,
#         [ 94, 109, 106],
#         [ 91, 103,  99],
#         [ 88, 100,  96]],
#
#        [[144, 146, 141],
#         [149, 151, 146],
#         [152, 154, 149],
#         ...,
#         [ 90, 104, 104],
#         [ 90, 101, 103],
#         [ 92, 103, 105]],
#
#        ...,
#
#        [[156, 166, 167],
#         [158, 168, 169],
#         [160, 170, 171],
#         ...,
#         [ 37,  35,  46],
#         [ 41,  39,  50],
#         [ 43,  41,  52]],
#
#        [[158, 170, 168],
#         [159, 171, 169],
#         [159, 171, 169],
#         ...,
#         [ 38,  35,  46],
#         [ 43,  39,  53],
#         [ 46,  42,  56]],
#
#        [[154, 169, 166],
#         [155, 170, 167],
#         [156, 168, 166],
#         ...,
#         [ 38,  35,  46],
#         [ 43,  39,  53],
#         [ 44,  40,  55]]], dtype=uint8)

# %% [markdown]
# ## 2.4 View Raw Images with Matplotlib

# %%
image_genarator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_genarator.next() #geting new batch of data, can be ran multiple time
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_images = image_genarator.next() #geting new batch of data, can be ran multiple time
#
# File ~\lab1\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4729, in NumpyIterator.next(self)
#    4728 def next(self):
# -> 4729   return self.__next__()
#
# File ~\lab1\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4726, in NumpyIterator.__next__(self)
#    4723     numpy.setflags(write=False)
#    4724   return numpy
# -> 4726 return nest.map_structure(to_numpy, next(self._iterator))
#
# File ~\lab1\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:809, in OwnedIterator.__next__(self)
#     807 def __next__(self):
#     808   try:
# --> 809     return self._next_internal()
#     810   except errors.OutOfRangeError:
#     811     raise StopIteration
#
# File ~\lab1\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:772, in OwnedIterator._next_internal(self)
#     769 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     770 # to communicate that there is no more data to iterate over.
#     771 with context.execution_mode(context.SYNC):
# --> 772   ret = gen_dataset_ops.iterator_get_next(
#     773       self._iterator_resource,
#     774       output_types=self._flat_output_types,
#     775       output_shapes=self._flat_output_shapes)
#     777   try:
#     778     # Fast path for the case `self._structure` is not a nested structure.
#     779     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~\lab1\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3086, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3084   return _result
#    3085 except _core._NotOkStatusException as e:
# -> 3086   _ops.raise_from_not_ok_status(e, name)
#    3087 except _core._FallbackException:
#    3088   pass
#
# File ~\lab1\Lib\site-packages\tensorflow\python\framework\ops.py:5983, in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__IteratorGetNext_output_types_1_device_/job:localhost/replica:0/task:0/device:CPU:0}} Cannot add tensor to the batch: number of elements does not match. Shapes are: [tensor]: [720,1280,3], [batch]: [480,640,3] [Op:IteratorGetNext] name:

# %%
#show 4 images, if you want another butch just ran cell below and then this one
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 fig, ax = plt.subplots(ncols=4, figsize=(20,20))
#       3 for idx, image in enumerate(plot_images):
# ----> 4     ax[idx].imshow(image)
#       5 plt.show()
#
# File ~\lab1\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File ~\lab1\Lib\site-packages\matplotlib\axes\_axes.py:5759, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5756 if aspect is not None:
#    5757     self.set_aspect(aspect)
# -> 5759 im.set_data(X)
#    5760 im.set_alpha(alpha)
#    5761 if im.get_clip_path() is None:
#    5762     # image does not already have clipping set, clip to axes patch
#
# File ~\lab1\Lib\site-packages\matplotlib\image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File ~\lab1\Lib\site-packages\matplotlib\image.py:688, in _ImageBase._normalize_image_array(A)
#     686 A = cbook.safe_masked_invalid(A, copy=True)
#     687 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 688     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     689                     f"converted to float")
#     690 if A.ndim == 3 and A.shape[-1] == 1:
#     691     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype |S52 cannot be converted to float

# %% [markdown]
# # 3. Partition Unaugmented Data

# %% [markdown]
# ## 3.1 Manually Split Sata into Train Test and Val

# %%
#if we add new data we need to also divide it and add to folders

# %%
180*0.7 #123 to train + 126
# Out:
# 125.99999999999999

# %%
180*.15 # 26 and 27 to test and val + 27 and 27
# Out:
# 27.0

# %% [markdown]
# ## 3.2 Move the Matching Labels

# %%
#moving matching labels to the photos in new folders
for folder in ['train', 'test', 'val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):
        filename = file.split('.')[0] + '.json'
        existing_filepath = os.path.join('data', 'labels', filename)
        if os.path.exists(existing_filepath):
            new_filepath = os.path.join('data', folder, 'labels', filename)
            os.replace(existing_filepath, new_filepath) 
#i'm not sure if it do it for all files but it did for some

# %% [markdown]
# # 4. Apply Image Augmentation on Images and Labels using Albumentations

# %% [markdown]
# ## 4.1 Setup Albumentations Transform Pipline

# %%
#adjust photos and normalization (bbox)
augmentor = alb.Compose([
    alb.RandomCrop(width=450, height=450),
    alb.HorizontalFlip(p=0.5),
    alb.RandomBrightnessContrast(p=0.2),
    alb.RandomGamma(p=0.2),
    alb.RGBShift(p=0.2),
    alb.VerticalFlip(p=0.5)
], bbox_params=alb.BboxParams(format='albumentations', label_fields=['class_labels']))

# %% [markdown]
# ## 4.2 Load a Test Image and Annotation with OpenCV and JSON

# %%
img = cv2.imread(os.path.join('data','train','images','d968a1b5-1aaf-11ef-b6d6-bd5cfcf36af4.jpg')) #if dosen't return error -> works

# %%
with open(os.path.join('data','train','labels','d968a1b5-1aaf-11ef-b6d6-bd5cfcf36af4.json'), 'r') as f:
    label = json.load(f)

# %%
#label #to check if it works, also can check type or use label['shapes'] or label['shapes'][0]['points'] for coordinate

# %%
label['shapes'][0]['label']
# Out:
# 'Ola'

# %% [markdown]
# ## 4.3 Extract Cooridnates and Rescale to Match Image Resolution

# %%
coords = [0,0,0,0]
coords[0]=label['shapes'][0]['points'][0][0]
coords[1]=label['shapes'][0]['points'][0][1]
coords[2]=label['shapes'][0]['points'][1][0]
coords[3]=label['shapes'][0]['points'][1][1]

# %%
coords #vector with coordinates
# Out:
# [405.6382978723404, 203.82978723404256, 563.0851063829787, 390.531914893617]

# %%
#this adjust to picture width and height and works better
img_width = img.shape[1] #x
img_height = img.shape[0] #y
coords = list(np.divide(coords, [img_width, img_height, img_width, img_height]))

# %%
coords
# Out:
# [0.6338098404255319, 0.424645390070922, 0.8798204787234042, 0.8136081560283688]

# %% [markdown]
# ## 4.4 Apply Augmentation and View Results

# %%
if label['shapes'][0]['label'] == 'face':
    class_lab = 'face'
elif label['shapes'][0]['label'] == 'Ola':
    class_lab = 'Ola'
else:
    class_lab = 'unknown'

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=[class_lab])

# %%
augmented['bboxes']
# Out:
# [(0.8391962174940899, 0.15659574468085113, 1.0, 0.5714893617021277)]

# %%
len(augmented['bboxes'])
# Out:
# 1

# %%
type(augmented['image'])
# Out:
# numpy.ndarray

# %%
cv2.rectangle(augmented['image'],
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)),
              (255,0,0),2)

plt.imshow(augmented['image']) #can be blue its still correct

# %% [markdown]
# # 5. Bulid and Run Augmentation Pipeline

# %% [markdown]
# ## 5.1 Run Augmentation Pipeline

# %%
for folder in ['train', 'test', 'val']:
    for image in os.listdir(os.path.join('data', folder, 'images')):
        img = cv2.imread(os.path.join('data', folder, 'images', image))

        coords = [0, 0, 0.00001, 0.00001]
        filename = image.split('.')[0] + '.json'
        label_path = os.path.join('data', folder, 'labels', filename)
        
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            img_width = img.shape[1] # x
            img_height = img.shape[0] # y
            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [img_width, img_height, img_width, img_height]))

        try:
            for x in range(60):  #create 60 new images for every image in Database
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                
                new_image_name = f'{image.split(".")[0]}_{x}.jpg'  
                cv2.imwrite(os.path.join('aug_data', folder, 'images', new_image_name), augmented['image'])

                annotation = {}
                annotation['image'] = image  

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bboxes'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        if label['shapes'][0]['label'] == 'face':
                            annotation['bboxes'] = augmented['bboxes'][0]
                            annotation['class'] = 1
                        else:
                            annotation['bboxes'] = augmented['bboxes'][0]
                            annotation['class'] = 2
                else:
                    annotation['bboxes'] = [0, 0, 0, 0]
                    annotation['class'] = 0

                with open(os.path.join('aug_data', folder, 'labels', f'{image.split(".")[0]}_{x}.json'), 'w') as f: 
                    json.dump(annotation, f)
        except Exception as e:
            print(e)
# Out:
# image must be numpy array type
# image must be numpy array type
# image must be numpy array type
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 23
#      21 try:
#      22     for x in range(60):  #create 60 new images for every image in Database
# ---> 23         augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
#      25         new_image_name = f'{image.split(".")[0]}_{x}.jpg'
#      26         cv2.imwrite(os.path.join('aug_data', folder, 'images', new_image_name), augmented['image'])
#
# File /usr/local/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/albumentations/core/composition.py:235, in Compose.__call__(self, force_apply, *args, **data)
#     233     if check_each_transform:
#     234         data = self._check_data_post_transform(data)
# --> 235 data = Compose._make_targets_contiguous(data)  # ensure output targets are contiguous
#     237 for p in self.processors.values():
#     238     p.postprocess(data)
#
# File /usr/local/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/albumentations/core/composition.py:314, in Compose._make_targets_contiguous(data)
#     312 for key, value in data.items():
#     313     if isinstance(value, np.ndarray):
# --> 314         result[key] = np.ascontiguousarray(value)
#     315     else:
#     316         result[key] = value
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5.2 Load Augmented Images to Tensorflow Dataset

# %%
train_images = tf.data.Dataset.list_files('aug_data/train/images/*.jpg', shuffle = False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/225) #scaling and resize towork better at network while teaching

# %%
test_images = tf.data.Dataset.list_files('aug_data/test/images/*.jpg', shuffle = False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/225)

# %%
val_images = tf.data.Dataset.list_files('aug_data/val/images/*.jpg', shuffle = False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/225)

# %% [markdown]
# # 6. Prepare Labels

# %% [markdown]
# ## 6.1 Build Label Loading Function

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)

    return [label['class']],label['bboxes']

# %% [markdown]
# ## 6.2 Load Labels to Tensorflow Dataset

# %%
train_labels = tf.data.Dataset.list_files('aug_data/train/labels/*.json', shuffle = False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
test_labels = tf.data.Dataset.list_files('aug_data/test/labels/*.json', shuffle = False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
val_labels = tf.data.Dataset.list_files('aug_data/val/labels/*.json', shuffle = False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %% [markdown]
# # 7. Combine Label and Image Samples

# %% [markdown]
# ## 7.1 Check Partition Lengths

# %%
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (14820, 14820, 3300, 3300, 3240, 3240)

# %% [markdown]
# ## 7.2 Create Final Datasets (Images/Labels)

# %%
train = tf.data.Dataset.zip((train_images,train_labels)) #combining 
train = train.shuffle(15000) #bigger than len(train_images)
train = train.batch(8) 
train = train.prefetch(4) #eliminate bottlenecks

# %%
test = tf.data.Dataset.zip((test_images,test_labels))
test = test.shuffle(3500)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images,val_labels))
val = val.shuffle(3500)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[0].shape #8 images, 120x120, 3 colors
# Out:
# 2024-05-26 13:04:50.460613: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 3584 of 15000
# 2024-05-26 13:05:00.463654: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 7758 of 15000
# 2024-05-26 13:05:20.460481: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 14505 of 15000
# 2024-05-26 13:05:21.172677: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# (8, 120, 120, 3)

# %% [markdown]
# ## 7.3 View Images and Annotation

# %%
data_sample=train.as_numpy_iterator()

# %%
res = data_sample.next()
# Out:
# 2024-05-26 13:05:32.038252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 4518 of 15000
# 2024-05-26 13:05:52.043824: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 13686 of 15000
# 2024-05-26 13:05:55.101254: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.

# %%
fif, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4):
    sample_image = res[0][idx]
    sample_coords = res[1][1][idx]

    # Normalizacja obrazu
    normalized_image_np = cv2.normalize(sample_image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

    sample_image_umat = cv2.UMat(normalized_image_np)
    # Wywołanie funkcji cv2.rectangle na obiekcie UMat
    cv2.rectangle(sample_image_umat,
              tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
              tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)),
              (255,0,0),2)

    # Wyświetlenie znormalizowanego obrazu
    ax[idx].imshow(sample_image_umat.get())
    # ax[idx].imshow(sample_image)

# %% [markdown]
# # 8. Build Deep Learning using the Functional API

# %% [markdown]
# ## 8.1 Import Layers and Base Network
# Zaimportowane też powyżej (razem ze wszystkimi)
#
# *Czym jest VGG16?*
# To model sieci neuronowej konwolucyjnej (CNN).
# Model VGG16 składa się z 16 warstw konwolucyjnych i poolingowych, a następnie warstw w pełni połączonych. Każda warstwa konwolucyjna w modelu VGG16 składa się z serii filtrów konwolucyjnych o małym rozmiarze (zazwyczaj 3x3) z funkcją aktywacji ReLU oraz warstw poolingowych, które zmniejszają wymiary przestrzenne map cech.

# %%
from tensorflow.keras.models import Model # bazowy model tesoflow
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical #do klasyfikacji

# %% [markdown]
# ## 8.2 Download VGG16

# %%
# odcinamy koniec, bo jest to model tylko do klasyfikacji, a końcówkę chcemy zastąpić regresją
vgg = VGG16(include_top=False)

# %%
vgg.summary() # wyświetla informację o sieciach neuronowych
# (ilość próbek, szerokość, wysokość, ilość kanałów)
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 8.3 Build instance of Network

# %%
# def build_model(): 
#     input_layer = Input(shape=(120,120,3)) # wejście o wymiarach 120x120x3 pikseli
    
#     vgg = VGG16(include_top=False)(input_layer)

#     # Model klasyfikacji  
#     f1 = GlobalMaxPooling2D()(vgg) # wyjścia w vgg
#     class1 = Dense(2048, activation='relu')(f1)
#     class2 = Dense(1, activation='sigmoid')(class1) # jedno wyjscie
    
#     # Model ramki ograniczającej
#     f2 = GlobalMaxPooling2D()(vgg) # jakoś kondensuje ilość wejść
#     regress1 = Dense(2048, activation='relu')(f2)
#     regress2 = Dense(4, activation='sigmoid')(regress1) # 4 wyjscia
    
#     facetracker = Model(inputs=input_layer, outputs=[class2, regress2]) # dwa wyjścia
#     # wyjście z klasyfikacji i wyjście z regresji
#     # class2 jest jedna wartoscia z przedzialu [0,1] ponieważ wykorzystuję sigmoidę
#     # regress2 sklada się z 4 elementów z przedziału [0,1]
#     return facetracker

# %%
def build_model(num_classes): 
    input_layer = Input(shape=(120,120,3)) # wejście o wymiarach 120x120x3 pikseli
    
    vgg = VGG16(include_top=False)(input_layer)

    # Model klasyfikacji  
    f1 = GlobalMaxPooling2D()(vgg) # wyjścia w vgg
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(num_classes, activation='softmax')(class1) # liczba klas wyjściowych
    
    # Model ramki ograniczającej
    f2 = GlobalMaxPooling2D()(vgg) # jakoś kondensuje ilość wejść
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1) # 4 wyjscia
    
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2]) # dwa wyjścia
    # wyjście z klasyfikacji i wyjście z regresji
    # class2 jest prawdopodobieństwem przynależności do każdej klasy, więc używamy softmax jako funkcji aktywacji
    # liczba klas zależy od twojego zbioru danych
    return facetracker

# %% [markdown]
# ## 8.4 Test out Neural Network

# %%
facetracker = build_model(3)#facetracker = build_model() #zdefiniuj model

# %%
facetracker.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 120, 120,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 3, 3, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │      6,147 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      8,196 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,830,279 (64.20 MB)
#  Trainable params: 16,830,279 (64.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X, y = train.as_numpy_iterator().next()
# Out:
# 2024-05-26 13:06:45.753377: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 4147 of 15000
# 2024-05-26 13:06:55.891768: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 6733 of 15000
# 2024-05-26 13:07:15.753051: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 9975 of 15000
# 2024-05-26 13:07:25.865431: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 11292 of 15000
# 2024-05-26 13:07:45.765027: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 13048 of 15000
# 2024-05-26 13:07:58.259195: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.

# %%
X.shape
# Out:
# (8, 120, 120, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# # 9. Define Losses and Optimizers

# %% [markdown]
# ## 9.1 Define Optimizer and LR

# %%
batches_per_epoch = len(train) # ilość danych uczących na epokę
lr_decay = (1./0.75 -1)/batches_per_epoch # spadek szybkości uczenia się
print('batches_per_epoch ' + str(batches_per_epoch) )
print('lr_decay ' + str(lr_decay))
# Out:
# batches_per_epoch 1853
# lr_decay 0.0001798884691491275

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)
# Out:
# /usr/local/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
def localization_loss(y_true, yhat):     
    # różnica pomiędzy rzeczywistym a przewidywanym koordynatem(rogiem)
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))

    # różnica pomiędzy rzeczywistymi a przewidywanymi długościami prostokąta
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))

    # zwraxa sumę błędów
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.CategoricalCrossentropy() #zmiana z binary na kategoriowy
regressloss = localization_loss

# %%
localization_loss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.3976784>

# %%
y_true_classes = to_categorical(y[0], num_classes=3)

# %%
class_loss_value = classloss(y_true_classes, classes)
# classloss(y[0], classes).numpy()

# %%
regressloss(y[1], coords)
# regressloss(y[1], coords).numpy()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.3976784>

# %% [markdown]
# # 10. Train Neural Network

# %% [markdown]
# ## 10.1 Create Custom Model Class

# %%
#gorąca jedynka
def preprocess_labels(y, num_classes):
    y_one_hot = tf.one_hot(y, depth=num_classes)
    y_one_hot = tf.reshape(y_one_hot, (-1, num_classes))  # Upewnij się, że kształt jest poprawny
    return y_one_hot

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker, num_classes, **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker
        self.num_classes = num_classes

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt

    @tf.function  # Decorate train_step with @tf.function
    def train_step(self, batch, **kwargs):
        X, y = batch

        with tf.GradientTape() as tape:
            try:
                classes, coords = self.model(X, training=True)

                # Zakodowanie etykiet w one-hot
                y_0 = preprocess_labels(y[0], self.num_classes)

                # Ustawienie kształtu tensorów
                y_0.set_shape([None, self.num_classes])
                classes.set_shape([None, self.num_classes])

                # Sprawdzenie kształtów tensorów
                tf.print("y_0 shape:", tf.shape(y_0))
                tf.print("classes shape:", tf.shape(classes))

                batch_classloss = self.closs(y_0, classes)
                batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
                total_loss = batch_localizationloss + 0.5 * batch_classloss

            except tf.errors.InvalidArgumentError as e:
                # Obsługuj przypadek, w którym y[0] może mieć rozmiar partii wynoszący zero (opcjonalnie)
                if 'Input tensors must be of size at least 1' in str(e):
                    return {"total_loss": tf.constant(0.0)}  # Dummy loss (opcjonalnie)
                else:
                    raise e  # Zakończ errorem

            grad = tape.gradient(total_loss, self.model.trainable_variables)
            self.opt.apply_gradients(zip(grad, self.model.trainable_variables))

        return {"total_loss": total_loss, "class_loss": batch_classloss, "regress_loss": batch_localizationloss}

    @tf.function  # Decorate test_step with @tf.function
    def test_step(self, batch, **kwargs):
        X, y = batch
        classes, coords = self.model(X, training=False)

        # Zakodowanie etykiet w one-hot
        y_0 = preprocess_labels(y[0], self.num_classes)

        # Ustawienie kształtu tensorów
        y_0.set_shape([None, self.num_classes])
        classes.set_shape([None, self.num_classes])

        # Sprawdzenie kształtów tensorów
        tf.print("y_0 shape:", tf.shape(y_0))
        tf.print("classes shape:", tf.shape(classes))

        batch_classloss = self.closs(y_0, classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss + 0.5 * batch_classloss
        return {"total_loss": total_loss, "class_loss": batch_classloss, "regress_loss": batch_localizationloss}


    def call(self, X, **kwargs):
        return self.model(X, **kwargs)

# %%
# class FaceTracker(Model): 
#     def __init__(self, eyetracker,  **kwargs): 
#         super().__init__(**kwargs)
#         self.model = eyetracker

#     def compile(self, opt, classloss, localizationloss, **kwargs):
#         super().compile(**kwargs)
#         self.closs = classloss
#         self.lloss = localizationloss
#         self.opt = opt

#     @tf.function  # Decorate train_step with @tf.function
#     def train_step(self, batch, **kwargs):
#         X, y = batch

#         with tf.GradientTape() as tape:
#           try:
#             classes, coords = self.model(X, training=True)

#             # Upewnij się, że y[0] ma zdefiniowaną range 
#             y_0 = tf.reshape(y[0], [-1, 1])  # Przykład: w razie potrzeby zmień kształt na (batch_size,1).
#             # Sprawdź format danych i odpowiednio zmień ich kształt

#             # Upewnij się, że klasy mają zdefiniowaną rangę (sprawdź kształt wyjściowy self.model(X,training=True))
#             # ... (w razie potrzeby zmień kształt klas w oparciu o dane wyjściowe modelu)

#             batch_classloss = self.closs(y_0, classes)
#             batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32),coords)
#             total_loss = batch_localizationloss + 0.5 * batch_classloss

#           except tf.errors.InvalidArgumentError as e:
#             # Obsługuj przypadek, w którym y[0] może mieć rozmiar partii wynoszący zero (opcjonalnie)
#             if 'Input tensors must be of size at least 1' in str(e):
#               return {"total_loss": tf.constant(0.0)}  # Dummy loss (opcjonalnie)
#             else:
#               raise e  # Zakończ errorem

#           grad = tape.gradient(total_loss, self.model.trainable_variables)
#           self.opt.apply_gradients(zip(grad, self.model.trainable_variables))

#         return {"total_loss": total_loss, "class_loss": batch_classloss, "regress_loss": batch_localizationloss}

#     def test_step(self, batch, **kwargs):
#         X, y = batch
#         classes, coords = self.model(X, training=False)

#         # Ensure y[0] has a defined rank (handle potential reshaping)
#         y_0 = tf.reshape(y[0], [-1, 1])  # Example: Reshape to (batch_size, 1)if needed
#         # Check your data format and reshape accordingly

#         # Ensure classes has a defined rank (check model output shape)
#         # ... (reshape classes if necessary based on your model's output)

#         batch_classloss = self.closs(y_0, classes)
#         batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
#         total_loss = batch_localizationloss + 0.5 * batch_classloss
#         return {"total_loss": total_loss, "class_loss": batch_classloss,"regress_loss": batch_localizationloss}

#     def call(self, X, **kwargs):
#         return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker,3) #bo aktualnie sa trzy klasy, mozna zmienic

# %%
model.compile(opt, classloss, regressloss)

# %% [markdown]
# # 10.2 Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
print("Shape of y[0]:", y[0].shape)
print("Shape of classes:", classes.shape)
# Out:
# Shape of y[0]: (8, 1)
# Shape of classes: (8, 3)

# %%
# powoduje wywołanie train_step    ODKOMENTUJ< JESLI CHCESZ UCZYC
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 2024-05-26 13:10:04.371261: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 4657 of 15000
# 2024-05-26 13:10:24.372417: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 14127 of 15000
# y_0 shape: [8 3]
# 2024-05-26 13:10:26.482208: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716721826.563017 3898697 service.cc:145] XLA service 0x600000cfea00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1716721826.565361 3898697 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2024-05-26 13:10:26.570877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1716721826.966655 3898697 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# classes shape: [8 3]
#    1/1853 ━━━━━━━━━━━━━━━━━━━━ 23:27:20 46s/step - class_loss: 1.3137 - regress_loss: 4.2776 - total_loss: 4.9344y_0 shape: [8 3]
# classes shape: [8 3]
#    2/1853 ━━━━━━━━━━━━━━━━━━━━ 1:26:48 3s/step - class_loss: 1.3204 - regress_loss: 3.4985 - total_loss: 4.1587  y_0 shape: [8 3]
# classes shape: [8 3]
#    3/1853 ━━━━━━━━━━━━━━━━━━━━ 1:27:07 3s/step - class_loss: 1.2385 - regress_loss: 3.1729 - total_loss: 3.7921y_0 shape: [8 3]
# classes shape: [8 3]
#    4/1853 ━━━━━━━━━━━━━━━━━━━━ 1:26:39 3s/step - class_loss: 1.2138 - regress_loss: 3.1455 - total_loss: 3.7524y_0 shape: [8 3]
# classes shape: [8 3]
#    5/1853 ━━━━━━━━━━━━━━━━━━━━ 1:25:25 3s/step - class_loss: 1.1940 - regress_loss: 2.9085 - total_loss: 3.5055y_0 shape: [8 3]
# classes shape: [8 3]
#    6/1853 ━━━━━━━━━━━━━━━━━━━━ 1:25:19 3s/step - class_loss: 1.1692 - regress_loss: 2.6794 - total_loss: 3.2640y_0 shape: [8 3]
# classes shape: [8 3]
#    7/1853 ━━━━━━━━━━━━━━━━━━━━ 1:25:29 3s/step - class_loss: 1.1391 - regress_loss: 2.4993 - total_loss: 3.0689y_0 shape: [8 3]
# classes shape: [8 3]
#    8/1853 ━━━━━━━━━━━━━━━━━━━━ 1:25:24 3s/step - class_loss: 1.1172 - regress_loss: 2.3824 - total_loss: 2.9410y_0 shape: [8 3]
# classes shape: [8 3]
#    9/1853 ━━━━━━━━━━━━━━━━━━━━ 1:25:14 3s/step - class_loss: 1.1124 - regress_loss: 2.3116 - total_loss: 2.8678y_0 shape: [8 3]
# classes shape: [8 3]
#   10/1853 ━━━━━━━━━━━━━━━━━━━━ 1:27:13 3s/step - class_loss: 1.0988 - regress_loss: 2.2932 - total_loss: 2.8426y_0 shape: [8 3]
# classes shape: [8 3]
#   11/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:53 3s/step - class_loss: 1.0984 - regress_loss: 2.2758 - total_loss: 2.8250y_0 shape: [8 3]
# classes shape: [8 3]
#   12/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:41 3s/step - class_loss: 1.1112 - regress_loss: 2.2839 - total_loss: 2.8395y_0 shape: [8 3]
# classes shape: [8 3]
#   13/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:09 3s/step - class_loss: 1.1022 - regress_loss: 2.2216 - total_loss: 2.7727y_0 shape: [8 3]
# classes shape: [8 3]
#   14/1853 ━━━━━━━━━━━━━━━━━━━━ 1:27:41 3s/step - class_loss: 1.0894 - regress_loss: 2.1727 - total_loss: 2.7174y_0 shape: [8 3]
# classes shape: [8 3]
#   15/1853 ━━━━━━━━━━━━━━━━━━━━ 1:27:31 3s/step - class_loss: 1.0934 - regress_loss: 2.1022 - total_loss: 2.6489y_0 shape: [8 3]
# classes shape: [8 3]
#   16/1853 ━━━━━━━━━━━━━━━━━━━━ 1:27:38 3s/step - class_loss: 1.0797 - regress_loss: 2.0798 - total_loss: 2.6197y_0 shape: [8 3]
# classes shape: [8 3]
#   17/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:38 3s/step - class_loss: 1.0829 - regress_loss: 2.1032 - total_loss: 2.6446y_0 shape: [8 3]
# classes shape: [8 3]
#   18/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:37 3s/step - class_loss: 1.0773 - regress_loss: 2.0730 - total_loss: 2.6117y_0 shape: [8 3]
# classes shape: [8 3]
#   19/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:14 3s/step - class_loss: 1.0675 - regress_loss: 2.0394 - total_loss: 2.5731y_0 shape: [8 3]
# classes shape: [8 3]
#   20/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:28 3s/step - class_loss: 1.0694 - regress_loss: 2.0478 - total_loss: 2.5825y_0 shape: [8 3]
# classes shape: [8 3]
#   21/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:22 3s/step - class_loss: 1.0559 - regress_loss: 2.0471 - total_loss: 2.5751y_0 shape: [8 3]
# classes shape: [8 3]
#   22/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:44 3s/step - class_loss: 1.0744 - regress_loss: 2.0705 - total_loss: 2.6077y_0 shape: [8 3]
# classes shape: [8 3]
#   23/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:53 3s/step - class_loss: 1.0655 - regress_loss: 2.0452 - total_loss: 2.5780y_0 shape: [8 3]
# classes shape: [8 3]
#   24/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:46 3s/step - class_loss: 1.0540 - regress_loss: 2.0039 - total_loss: 2.5309y_0 shape: [8 3]
# classes shape: [8 3]
#   25/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:33 3s/step - class_loss: 1.0396 - regress_loss: 1.9623 - total_loss: 2.4821y_0 shape: [8 3]
# classes shape: [8 3]
#   26/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:43 3s/step - class_loss: 1.0225 - regress_loss: 1.9106 - total_loss: 2.4218y_0 shape: [8 3]
# classes shape: [8 3]
#   27/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:36 3s/step - class_loss: 1.0119 - regress_loss: 1.8912 - total_loss: 2.3971y_0 shape: [8 3]
# classes shape: [8 3]
#   28/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:43 3s/step - class_loss: 0.9993 - regress_loss: 1.8729 - total_loss: 2.3725y_0 shape: [8 3]
# classes shape: [8 3]
#   29/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:27 3s/step - class_loss: 0.9798 - regress_loss: 1.8429 - total_loss: 2.3328y_0 shape: [8 3]
# classes shape: [8 3]
#   30/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:08 3s/step - class_loss: 0.9765 - regress_loss: 1.8207 - total_loss: 2.3090y_0 shape: [8 3]
# classes shape: [8 3]
#   31/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:19 3s/step - class_loss: 0.9671 - regress_loss: 1.7990 - total_loss: 2.2825y_0 shape: [8 3]
# classes shape: [8 3]
#   32/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:30 3s/step - class_loss: 0.9569 - regress_loss: 1.7886 - total_loss: 2.2670y_0 shape: [8 3]
# classes shape: [8 3]
#   33/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:43 3s/step - class_loss: 0.9543 - regress_loss: 1.7950 - total_loss: 2.2721y_0 shape: [8 3]
# classes shape: [8 3]
#   34/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:53 3s/step - class_loss: 0.9332 - regress_loss: 1.7531 - total_loss: 2.2197y_0 shape: [8 3]
# classes shape: [8 3]
#   35/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:53 3s/step - class_loss: 0.9270 - regress_loss: 1.7443 - total_loss: 2.2078y_0 shape: [8 3]
# classes shape: [8 3]
#   36/1853 ━━━━━━━━━━━━━━━━━━━━ 1:28:59 3s/step - class_loss: 0.9160 - regress_loss: 1.7367 - total_loss: 2.1947y_0 shape: [8 3]
# classes shape: [8 3]
#   37/1853 ━━━━━━━━━━━━━━━━━━━━ 1:29:09 3s/step - class_loss: 0.9057 - regress_loss: 1.7307 - total_loss: 2.1836y_0 shape: [8 3]
# classes shape: [8 3]
#   38/1853 ━━━━━━━━━━━━━━━━━━━━ 1:29:31 3s/step - class_loss: 0.8992 - regress_loss: 1.7169 - total_loss: 2.1665y_0 shape: [8 3]
# classes shape: [8 3]
#   39/1853 ━━━━━━━━━━━━━━━━━━━━ 1:30:27 3s/step - class_loss: 0.8895 - regress_loss: 1.7001 - total_loss: 2.1448y_0 shape: [8 3]
# classes shape: [8 3]
#   40/1853 ━━━━━━━━━━━━━━━━━━━━ 1:30:32 3s/step - class_loss: 0.8753 - regress_loss: 1.6809 - total_loss: 2.1185y_0 shape: [8 3]
# classes shape: [8 3]
#   41/1853 ━━━━━━━━━━━━━━━━━━━━ 1:30:53 3s/step - class_loss: 0.8700 - regress_loss: 1.6946 - total_loss: 2.1296y_0 shape: [8 3]
# classes shape: [8 3]
#   42/1853 ━━━━━━━━━━━━━━━━━━━━ 1:32:36 3s/step - class_loss: 0.8539 - regress_loss: 1.6684 - total_loss: 2.0954y_0 shape: [8 3]
# classes shape: [8 3]
#   43/1853 ━━━━━━━━━━━━━━━━━━━━ 1:34:43 3s/step - class_loss: 0.8487 - regress_loss: 1.6701 - total_loss: 2.0945y_0 shape: [8 3]
# classes shape: [8 3]
#   44/1853 ━━━━━━━━━━━━━━━━━━━━ 1:35:57 3s/step - class_loss: 0.8369 - regress_loss: 1.6497 - total_loss: 2.0681y_0 shape: [8 3]
# classes shape: [8 3]
#   45/1853 ━━━━━━━━━━━━━━━━━━━━ 1:36:38 3s/step - class_loss: 0.8300 - regress_loss: 1.6507 - total_loss: 2.0657y_0 shape: [8 3]
# classes shape: [8 3]
#   46/1853 ━━━━━━━━━━━━━━━━━━━━ 1:36:29 3s/step - class_loss: 0.8355 - regress_loss: 1.6598 - total_loss: 2.0775y_0 shape: [8 3]
# classes shape: [8 3]
#   47/1853 ━━━━━━━━━━━━━━━━━━━━ 1:36:41 3s/step - class_loss: 0.8257 - regress_loss: 1.6567 - total_loss: 2.0695y_0 shape: [8 3]
# classes shape: [8 3]
#   48/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:19 3s/step - class_loss: 0.8170 - regress_loss: 1.6719 - total_loss: 2.0804y_0 shape: [8 3]
# classes shape: [8 3]
#   49/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:17 3s/step - class_loss: 0.8109 - regress_loss: 1.6644 - total_loss: 2.0698y_0 shape: [8 3]
# classes shape: [8 3]
#   50/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:14 3s/step - class_loss: 0.8116 - regress_loss: 1.6647 - total_loss: 2.0705y_0 shape: [8 3]
# classes shape: [8 3]
#   51/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:38 3s/step - class_loss: 0.8037 - regress_loss: 1.6565 - total_loss: 2.0583y_0 shape: [8 3]
# classes shape: [8 3]
#   52/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:16 3s/step - class_loss: 0.7943 - regress_loss: 1.6478 - total_loss: 2.0450y_0 shape: [8 3]
# classes shape: [8 3]
#   53/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:42 3s/step - class_loss: 0.7856 - regress_loss: 1.6354 - total_loss: 2.0282y_0 shape: [8 3]
# classes shape: [8 3]
#   54/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:32 3s/step - class_loss: 0.7752 - regress_loss: 1.6198 - total_loss: 2.0074y_0 shape: [8 3]
# classes shape: [8 3]
#   55/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:16 3s/step - class_loss: 0.7730 - regress_loss: 1.6182 - total_loss: 2.0047y_0 shape: [8 3]
# classes shape: [8 3]
#   56/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:02 3s/step - class_loss: 0.7724 - regress_loss: 1.6139 - total_loss: 2.0001y_0 shape: [8 3]
# classes shape: [8 3]
#   57/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:58 3s/step - class_loss: 0.7636 - regress_loss: 1.5965 - total_loss: 1.9782y_0 shape: [8 3]
# classes shape: [8 3]
#   58/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:13 3s/step - class_loss: 0.7536 - regress_loss: 1.5753 - total_loss: 1.9521y_0 shape: [8 3]
# classes shape: [8 3]
#   59/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:13 3s/step - class_loss: 0.7486 - regress_loss: 1.5751 - total_loss: 1.9494y_0 shape: [8 3]
# classes shape: [8 3]
#   60/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:12 3s/step - class_loss: 0.7403 - regress_loss: 1.5611 - total_loss: 1.9312y_0 shape: [8 3]
# classes shape: [8 3]
#   61/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:12 3s/step - class_loss: 0.7328 - regress_loss: 1.5484 - total_loss: 1.9148y_0 shape: [8 3]
# classes shape: [8 3]
#   62/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:57 3s/step - class_loss: 0.7242 - regress_loss: 1.5373 - total_loss: 1.8994y_0 shape: [8 3]
# classes shape: [8 3]
#   63/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:51 3s/step - class_loss: 0.7172 - regress_loss: 1.5266 - total_loss: 1.8852y_0 shape: [8 3]
# classes shape: [8 3]
#   64/1853 ━━━━━━━━━━━━━━━━━━━━ 1:37:45 3s/step - class_loss: 0.7161 - regress_loss: 1.5204 - total_loss: 1.8784y_0 shape: [8 3]
# classes shape: [8 3]
#   65/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:09 3s/step - class_loss: 0.7109 - regress_loss: 1.5213 - total_loss: 1.8768y_0 shape: [8 3]
# classes shape: [8 3]
#   66/1853 ━━━━━━━━━━━━━━━━━━━━ 1:38:30 3s/step - class_loss: 0.7031 - regress_loss: 1.5110 - total_loss: 1.8625y_0 shape: [8 3]
# classes shape: [8 3]
#   67/1853 ━━━━━━━━━━━━━━━━━━━━ 1:39:08 3s/step - class_loss: 0.6948 - regress_loss: 1.4996 - total_loss: 1.8470y_0 shape: [8 3]
# classes shape: [8 3]
#   68/1853 ━━━━━━━━━━━━━━━━━━━━ 1:39:09 3s/step - class_loss: 0.6872 - regress_loss: 1.4848 - total_loss: 1.8283y_0 shape: [8 3]
# classes shape: [8 3]
#   69/1853 ━━━━━━━━━━━━━━━━━━━━ 1:39:45 3s/step - class_loss: 0.6813 - regress_loss: 1.4785 - total_loss: 1.8191y_0 shape: [8 3]
# classes shape: [8 3]
#   70/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:09 3s/step - class_loss: 0.6736 - regress_loss: 1.4673 - total_loss: 1.8041y_0 shape: [8 3]
# classes shape: [8 3]
#   71/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:53 3s/step - class_loss: 0.6709 - regress_loss: 1.4731 - total_loss: 1.8086y_0 shape: [8 3]
# classes shape: [8 3]
#   72/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:04 4s/step - class_loss: 0.6672 - regress_loss: 1.4680 - total_loss: 1.8016y_0 shape: [8 3]
# classes shape: [8 3]
#   73/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:36 4s/step - class_loss: 0.6606 - regress_loss: 1.4623 - total_loss: 1.7926y_0 shape: [8 3]
# classes shape: [8 3]
#   74/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:58 4s/step - class_loss: 0.6544 - regress_loss: 1.4570 - total_loss: 1.7843y_0 shape: [8 3]
# classes shape: [8 3]
#   75/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:00 4s/step - class_loss: 0.6462 - regress_loss: 1.4406 - total_loss: 1.7637y_0 shape: [8 3]
# classes shape: [8 3]
#   76/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:21 4s/step - class_loss: 0.6393 - regress_loss: 1.4293 - total_loss: 1.7490y_0 shape: [8 3]
# classes shape: [8 3]
#   77/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:41 4s/step - class_loss: 0.6327 - regress_loss: 1.4198 - total_loss: 1.7361y_0 shape: [8 3]
# classes shape: [8 3]
#   78/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:50 4s/step - class_loss: 0.6261 - regress_loss: 1.4073 - total_loss: 1.7204y_0 shape: [8 3]
# classes shape: [8 3]
#   79/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:29 4s/step - class_loss: 0.6204 - regress_loss: 1.3971 - total_loss: 1.7073y_0 shape: [8 3]
# classes shape: [8 3]
#   80/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:56 4s/step - class_loss: 0.6220 - regress_loss: 1.3978 - total_loss: 1.7088y_0 shape: [8 3]
# classes shape: [8 3]
#   81/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:12 4s/step - class_loss: 0.6152 - regress_loss: 1.3853 - total_loss: 1.6929y_0 shape: [8 3]
# classes shape: [8 3]
#   82/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:20 4s/step - class_loss: 0.6102 - regress_loss: 1.3778 - total_loss: 1.6829y_0 shape: [8 3]
# classes shape: [8 3]
#   83/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:16 4s/step - class_loss: 0.6062 - regress_loss: 1.3703 - total_loss: 1.6734y_0 shape: [8 3]
# classes shape: [8 3]
#   84/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:16 4s/step - class_loss: 0.6025 - regress_loss: 1.3596 - total_loss: 1.6609y_0 shape: [8 3]
# classes shape: [8 3]
#   85/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:08 4s/step - class_loss: 0.6037 - regress_loss: 1.3574 - total_loss: 1.6592y_0 shape: [8 3]
# classes shape: [8 3]
#   86/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:02 4s/step - class_loss: 0.5980 - regress_loss: 1.3541 - total_loss: 1.6530y_0 shape: [8 3]
# classes shape: [8 3]
#   87/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:23 4s/step - class_loss: 0.5927 - regress_loss: 1.3487 - total_loss: 1.6451y_0 shape: [8 3]
# classes shape: [8 3]
#   88/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:32 4s/step - class_loss: 0.5891 - regress_loss: 1.3406 - total_loss: 1.6352y_0 shape: [8 3]
# classes shape: [8 3]
#   89/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:15 4s/step - class_loss: 0.5844 - regress_loss: 1.3349 - total_loss: 1.6271y_0 shape: [8 3]
# classes shape: [8 3]
#   90/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:54 4s/step - class_loss: 0.5796 - regress_loss: 1.3268 - total_loss: 1.6166y_0 shape: [8 3]
# classes shape: [8 3]
#   91/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:51 4s/step - class_loss: 0.5779 - regress_loss: 1.3224 - total_loss: 1.6113y_0 shape: [8 3]
# classes shape: [8 3]
#   92/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:46 4s/step - class_loss: 0.5744 - regress_loss: 1.3172 - total_loss: 1.6044y_0 shape: [8 3]
# classes shape: [8 3]
#   93/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:14 4s/step - class_loss: 0.5689 - regress_loss: 1.3088 - total_loss: 1.5933y_0 shape: [8 3]
# classes shape: [8 3]
#   94/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:15 4s/step - class_loss: 0.5640 - regress_loss: 1.2999 - total_loss: 1.5819y_0 shape: [8 3]
# classes shape: [8 3]
#   95/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:19 4s/step - class_loss: 0.5619 - regress_loss: 1.2932 - total_loss: 1.5741y_0 shape: [8 3]
# classes shape: [8 3]
#   96/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:24 4s/step - class_loss: 0.5563 - regress_loss: 1.2843 - total_loss: 1.5624y_0 shape: [8 3]
# classes shape: [8 3]
#   97/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:50 4s/step - class_loss: 0.5513 - regress_loss: 1.2770 - total_loss: 1.5526y_0 shape: [8 3]
# classes shape: [8 3]
#   98/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:50 4s/step - class_loss: 0.5459 - regress_loss: 1.2662 - total_loss: 1.5391y_0 shape: [8 3]
# classes shape: [8 3]
#   99/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:07 4s/step - class_loss: 0.5445 - regress_loss: 1.2613 - total_loss: 1.5336y_0 shape: [8 3]
# classes shape: [8 3]
#  100/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:41 4s/step - class_loss: 0.5395 - regress_loss: 1.2540 - total_loss: 1.5237y_0 shape: [8 3]
# classes shape: [8 3]
#  101/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:58 4s/step - class_loss: 0.5344 - regress_loss: 1.2448 - total_loss: 1.5120y_0 shape: [8 3]
# classes shape: [8 3]
#  102/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:02 4s/step - class_loss: 0.5347 - regress_loss: 1.2475 - total_loss: 1.5148y_0 shape: [8 3]
# classes shape: [8 3]
#  103/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:07 4s/step - class_loss: 0.5300 - regress_loss: 1.2394 - total_loss: 1.5044y_0 shape: [8 3]
# classes shape: [8 3]
#  104/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:29 4s/step - class_loss: 0.5261 - regress_loss: 1.2321 - total_loss: 1.4951y_0 shape: [8 3]
# classes shape: [8 3]
#  105/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:31 4s/step - class_loss: 0.5236 - regress_loss: 1.2250 - total_loss: 1.4867y_0 shape: [8 3]
# classes shape: [8 3]
#  106/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:33 4s/step - class_loss: 0.5266 - regress_loss: 1.2277 - total_loss: 1.4910y_0 shape: [8 3]
# classes shape: [8 3]
#  107/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:44 4s/step - class_loss: 0.5231 - regress_loss: 1.2197 - total_loss: 1.4812y_0 shape: [8 3]
# classes shape: [8 3]
#  108/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:52 4s/step - class_loss: 0.5199 - regress_loss: 1.2129 - total_loss: 1.4729y_0 shape: [8 3]
# classes shape: [8 3]
#  109/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:53 4s/step - class_loss: 0.5167 - regress_loss: 1.2084 - total_loss: 1.4667y_0 shape: [8 3]
# classes shape: [8 3]
#  110/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:41 4s/step - class_loss: 0.5133 - regress_loss: 1.2032 - total_loss: 1.4599y_0 shape: [8 3]
# classes shape: [8 3]
#  111/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:36 4s/step - class_loss: 0.5091 - regress_loss: 1.1961 - total_loss: 1.4507y_0 shape: [8 3]
# classes shape: [8 3]
#  112/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:27 4s/step - class_loss: 0.5098 - regress_loss: 1.1987 - total_loss: 1.4537y_0 shape: [8 3]
# classes shape: [8 3]
#  113/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:29 4s/step - class_loss: 0.5067 - regress_loss: 1.1911 - total_loss: 1.4444y_0 shape: [8 3]
# classes shape: [8 3]
#  114/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:32 4s/step - class_loss: 0.5025 - regress_loss: 1.1838 - total_loss: 1.4351y_0 shape: [8 3]
# classes shape: [8 3]
#  115/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:28 4s/step - class_loss: 0.4984 - regress_loss: 1.1763 - total_loss: 1.4255y_0 shape: [8 3]
# classes shape: [8 3]
#  116/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:40 4s/step - class_loss: 0.4944 - regress_loss: 1.1697 - total_loss: 1.4169y_0 shape: [8 3]
# classes shape: [8 3]
#  117/1853 ━━━━━━━━━━━━━━━━━━━━ 1:54:03 4s/step - class_loss: 0.4913 - regress_loss: 1.1644 - total_loss: 1.4101y_0 shape: [8 3]
# classes shape: [8 3]
#  118/1853 ━━━━━━━━━━━━━━━━━━━━ 1:54:04 4s/step - class_loss: 0.4872 - regress_loss: 1.1559 - total_loss: 1.3995y_0 shape: [8 3]
# classes shape: [8 3]
#  119/1853 ━━━━━━━━━━━━━━━━━━━━ 1:54:13 4s/step - class_loss: 0.4832 - regress_loss: 1.1530 - total_loss: 1.3946y_0 shape: [8 3]
# classes shape: [8 3]
#  120/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:53 4s/step - class_loss: 0.4829 - regress_loss: 1.1560 - total_loss: 1.3975y_0 shape: [8 3]
# classes shape: [8 3]
#  121/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:31 4s/step - class_loss: 0.4794 - regress_loss: 1.1487 - total_loss: 1.3884y_0 shape: [8 3]
# classes shape: [8 3]
#  122/1853 ━━━━━━━━━━━━━━━━━━━━ 1:53:11 4s/step - class_loss: 0.4758 - regress_loss: 1.1417 - total_loss: 1.3796y_0 shape: [8 3]
# classes shape: [8 3]
#  123/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:51 4s/step - class_loss: 0.4724 - regress_loss: 1.1355 - total_loss: 1.3717y_0 shape: [8 3]
# classes shape: [8 3]
#  124/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:31 4s/step - class_loss: 0.4708 - regress_loss: 1.1301 - total_loss: 1.3655y_0 shape: [8 3]
# classes shape: [8 3]
#  125/1853 ━━━━━━━━━━━━━━━━━━━━ 1:52:10 4s/step - class_loss: 0.4680 - regress_loss: 1.1240 - total_loss: 1.3580y_0 shape: [8 3]
# classes shape: [8 3]
#  126/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:52 4s/step - class_loss: 0.4649 - regress_loss: 1.1210 - total_loss: 1.3534y_0 shape: [8 3]
# classes shape: [8 3]
#  127/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:45 4s/step - class_loss: 0.4644 - regress_loss: 1.1173 - total_loss: 1.3495y_0 shape: [8 3]
# classes shape: [8 3]
#  128/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:32 4s/step - class_loss: 0.4612 - regress_loss: 1.1126 - total_loss: 1.3431y_0 shape: [8 3]
# classes shape: [8 3]
#  129/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:25 4s/step - class_loss: 0.4580 - regress_loss: 1.1059 - total_loss: 1.3349y_0 shape: [8 3]
# classes shape: [8 3]
#  130/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:14 4s/step - class_loss: 0.4582 - regress_loss: 1.1041 - total_loss: 1.3331y_0 shape: [8 3]
# classes shape: [8 3]
#  131/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:54 4s/step - class_loss: 0.4553 - regress_loss: 1.0981 - total_loss: 1.3258y_0 shape: [8 3]
# classes shape: [8 3]
#  132/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:38 4s/step - class_loss: 0.4521 - regress_loss: 1.0914 - total_loss: 1.3175y_0 shape: [8 3]
# classes shape: [8 3]
#  133/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:19 4s/step - class_loss: 0.4518 - regress_loss: 1.0923 - total_loss: 1.3183y_0 shape: [8 3]
# classes shape: [8 3]
#  134/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:03 4s/step - class_loss: 0.4513 - regress_loss: 1.0910 - total_loss: 1.3167y_0 shape: [8 3]
# classes shape: [8 3]
#  135/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:44 4s/step - class_loss: 0.4481 - regress_loss: 1.0863 - total_loss: 1.3104y_0 shape: [8 3]
# classes shape: [8 3]
#  136/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:26 4s/step - class_loss: 0.4452 - regress_loss: 1.0841 - total_loss: 1.3067y_0 shape: [8 3]
# classes shape: [8 3]
#  137/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:10 4s/step - class_loss: 0.4429 - regress_loss: 1.0832 - total_loss: 1.3046y_0 shape: [8 3]
# classes shape: [8 3]
#  138/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:53 4s/step - class_loss: 0.4402 - regress_loss: 1.0830 - total_loss: 1.3031y_0 shape: [8 3]
# classes shape: [8 3]
#  139/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:37 4s/step - class_loss: 0.4378 - regress_loss: 1.0807 - total_loss: 1.2997y_0 shape: [8 3]
# classes shape: [8 3]
#  140/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:21 4s/step - class_loss: 0.4362 - regress_loss: 1.0779 - total_loss: 1.2960y_0 shape: [8 3]
# classes shape: [8 3]
#  141/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:03 4s/step - class_loss: 0.4339 - regress_loss: 1.0761 - total_loss: 1.2931y_0 shape: [8 3]
# classes shape: [8 3]
#  142/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:49 4s/step - class_loss: 0.4308 - regress_loss: 1.0717 - total_loss: 1.2871y_0 shape: [8 3]
# classes shape: [8 3]
#  143/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:35 4s/step - class_loss: 0.4313 - regress_loss: 1.0718 - total_loss: 1.2875y_0 shape: [8 3]
# classes shape: [8 3]
#  144/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:23 4s/step - class_loss: 0.4285 - regress_loss: 1.0689 - total_loss: 1.2831y_0 shape: [8 3]
# classes shape: [8 3]
#  145/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:06 4s/step - class_loss: 0.4265 - regress_loss: 1.0628 - total_loss: 1.2760y_0 shape: [8 3]
# classes shape: [8 3]
#  146/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:50 4s/step - class_loss: 0.4253 - regress_loss: 1.0600 - total_loss: 1.2727y_0 shape: [8 3]
# classes shape: [8 3]
#  147/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:41 4s/step - class_loss: 0.4233 - regress_loss: 1.0574 - total_loss: 1.2691y_0 shape: [8 3]
# classes shape: [8 3]
#  148/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:25 4s/step - class_loss: 0.4215 - regress_loss: 1.0582 - total_loss: 1.2690y_0 shape: [8 3]
# classes shape: [8 3]
#  149/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:11 4s/step - class_loss: 0.4224 - regress_loss: 1.0573 - total_loss: 1.2684y_0 shape: [8 3]
# classes shape: [8 3]
#  150/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:55 4s/step - class_loss: 0.4208 - regress_loss: 1.0553 - total_loss: 1.2657y_0 shape: [8 3]
# classes shape: [8 3]
#  151/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:42 4s/step - class_loss: 0.4191 - regress_loss: 1.0514 - total_loss: 1.2610y_0 shape: [8 3]
# classes shape: [8 3]
#  152/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:27 4s/step - class_loss: 0.4175 - regress_loss: 1.0478 - total_loss: 1.2565y_0 shape: [8 3]
# classes shape: [8 3]
#  153/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:12 4s/step - class_loss: 0.4173 - regress_loss: 1.0511 - total_loss: 1.2598y_0 shape: [8 3]
# classes shape: [8 3]
#  154/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:58 4s/step - class_loss: 0.4164 - regress_loss: 1.0489 - total_loss: 1.2571y_0 shape: [8 3]
# classes shape: [8 3]
#  155/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:43 4s/step - class_loss: 0.4162 - regress_loss: 1.0474 - total_loss: 1.2555y_0 shape: [8 3]
# classes shape: [8 3]
#  156/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:31 4s/step - class_loss: 0.4141 - regress_loss: 1.0450 - total_loss: 1.2520y_0 shape: [8 3]
# classes shape: [8 3]
#  157/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:16 4s/step - class_loss: 0.4137 - regress_loss: 1.0414 - total_loss: 1.2482y_0 shape: [8 3]
# classes shape: [8 3]
#  158/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:02 4s/step - class_loss: 0.4127 - regress_loss: 1.0382 - total_loss: 1.2445y_0 shape: [8 3]
# classes shape: [8 3]
#  159/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:54 4s/step - class_loss: 0.4116 - regress_loss: 1.0351 - total_loss: 1.2409y_0 shape: [8 3]
# classes shape: [8 3]
#  160/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:42 4s/step - class_loss: 0.4097 - regress_loss: 1.0320 - total_loss: 1.2368y_0 shape: [8 3]
# classes shape: [8 3]
#  161/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:28 4s/step - class_loss: 0.4077 - regress_loss: 1.0276 - total_loss: 1.2314y_0 shape: [8 3]
# classes shape: [8 3]
#  162/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:16 4s/step - class_loss: 0.4089 - regress_loss: 1.0295 - total_loss: 1.2340y_0 shape: [8 3]
# classes shape: [8 3]
#  163/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:02 4s/step - class_loss: 0.4069 - regress_loss: 1.0264 - total_loss: 1.2299y_0 shape: [8 3]
# classes shape: [8 3]
#  164/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:50 4s/step - class_loss: 0.4045 - regress_loss: 1.0247 - total_loss: 1.2270y_0 shape: [8 3]
# classes shape: [8 3]
#  165/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:47 4s/step - class_loss: 0.4039 - regress_loss: 1.0244 - total_loss: 1.2263y_0 shape: [8 3]
# classes shape: [8 3]
#  166/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:41 4s/step - class_loss: 0.4055 - regress_loss: 1.0236 - total_loss: 1.2264y_0 shape: [8 3]
# classes shape: [8 3]
#  167/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:47 4s/step - class_loss: 0.4074 - regress_loss: 1.0257 - total_loss: 1.2294y_0 shape: [8 3]
# classes shape: [8 3]
#  168/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:45 4s/step - class_loss: 0.4059 - regress_loss: 1.0215 - total_loss: 1.2245y_0 shape: [8 3]
# classes shape: [8 3]
#  169/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:31 4s/step - class_loss: 0.4038 - regress_loss: 1.0171 - total_loss: 1.2190y_0 shape: [8 3]
# classes shape: [8 3]
#  170/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:19 4s/step - class_loss: 0.4032 - regress_loss: 1.0139 - total_loss: 1.2156y_0 shape: [8 3]
# classes shape: [8 3]
#  171/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:10 4s/step - class_loss: 0.4037 - regress_loss: 1.0112 - total_loss: 1.2131y_0 shape: [8 3]
# classes shape: [8 3]
#  172/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:59 4s/step - class_loss: 0.4027 - regress_loss: 1.0079 - total_loss: 1.2092y_0 shape: [8 3]
# classes shape: [8 3]
#  173/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:47 4s/step - class_loss: 0.4010 - regress_loss: 1.0042 - total_loss: 1.2047y_0 shape: [8 3]
# classes shape: [8 3]
#  174/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:34 4s/step - class_loss: 0.3993 - regress_loss: 1.0013 - total_loss: 1.2009y_0 shape: [8 3]
# classes shape: [8 3]
#  175/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:30 4s/step - class_loss: 0.3971 - regress_loss: 0.9962 - total_loss: 1.1947y_0 shape: [8 3]
# classes shape: [8 3]
#  176/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:22 4s/step - class_loss: 0.3950 - regress_loss: 0.9935 - total_loss: 1.1910y_0 shape: [8 3]
# classes shape: [8 3]
#  177/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:28 4s/step - class_loss: 0.3929 - regress_loss: 0.9897 - total_loss: 1.1862y_0 shape: [8 3]
# classes shape: [8 3]
#  178/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:25 4s/step - class_loss: 0.3911 - regress_loss: 0.9864 - total_loss: 1.1819y_0 shape: [8 3]
# classes shape: [8 3]
#  179/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:30 4s/step - class_loss: 0.3905 - regress_loss: 0.9866 - total_loss: 1.1819y_0 shape: [8 3]
# classes shape: [8 3]
#  180/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:31 4s/step - class_loss: 0.3895 - regress_loss: 0.9890 - total_loss: 1.1837y_0 shape: [8 3]
# classes shape: [8 3]
#  181/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:26 4s/step - class_loss: 0.3879 - regress_loss: 0.9856 - total_loss: 1.1796y_0 shape: [8 3]
# classes shape: [8 3]
#  182/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:14 4s/step - class_loss: 0.3860 - regress_loss: 0.9819 - total_loss: 1.1749y_0 shape: [8 3]
# classes shape: [8 3]
#  183/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:30 4s/step - class_loss: 0.3842 - regress_loss: 0.9783 - total_loss: 1.1704y_0 shape: [8 3]
# classes shape: [8 3]
#  184/1853 ━━━━━━━━━━━━━━━━━━━━ 1:41:41 4s/step - class_loss: 0.3822 - regress_loss: 0.9745 - total_loss: 1.1656y_0 shape: [8 3]
# classes shape: [8 3]
#  185/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:23 4s/step - class_loss: 0.3811 - regress_loss: 0.9740 - total_loss: 1.1646y_0 shape: [8 3]
# classes shape: [8 3]
#  186/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:17 4s/step - class_loss: 0.3801 - regress_loss: 0.9702 - total_loss: 1.1602y_0 shape: [8 3]
# classes shape: [8 3]
#  187/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:00 4s/step - class_loss: 0.3788 - regress_loss: 0.9665 - total_loss: 1.1559y_0 shape: [8 3]
# classes shape: [8 3]
#  188/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:04 4s/step - class_loss: 0.3772 - regress_loss: 0.9632 - total_loss: 1.1518y_0 shape: [8 3]
# classes shape: [8 3]
#  189/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:44 4s/step - class_loss: 0.3769 - regress_loss: 0.9621 - total_loss: 1.1505y_0 shape: [8 3]
# classes shape: [8 3]
#  190/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:17 4s/step - class_loss: 0.3761 - regress_loss: 0.9597 - total_loss: 1.1478y_0 shape: [8 3]
# classes shape: [8 3]
#  191/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:43 4s/step - class_loss: 0.3748 - regress_loss: 0.9565 - total_loss: 1.1439y_0 shape: [8 3]
# classes shape: [8 3]
#  192/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:59 4s/step - class_loss: 0.3732 - regress_loss: 0.9536 - total_loss: 1.1403y_0 shape: [8 3]
# classes shape: [8 3]
#  193/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:28 4s/step - class_loss: 0.3713 - regress_loss: 0.9500 - total_loss: 1.1357y_0 shape: [8 3]
# classes shape: [8 3]
#  194/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:47 4s/step - class_loss: 0.3699 - regress_loss: 0.9491 - total_loss: 1.1341y_0 shape: [8 3]
# classes shape: [8 3]
#  195/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:12 4s/step - class_loss: 0.3693 - regress_loss: 0.9464 - total_loss: 1.1311y_0 shape: [8 3]
# classes shape: [8 3]
#  196/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:34 4s/step - class_loss: 0.3676 - regress_loss: 0.9446 - total_loss: 1.1284y_0 shape: [8 3]
# classes shape: [8 3]
#  197/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:46 4s/step - class_loss: 0.3670 - regress_loss: 0.9427 - total_loss: 1.1262y_0 shape: [8 3]
# classes shape: [8 3]
#  198/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:10 4s/step - class_loss: 0.3654 - regress_loss: 0.9392 - total_loss: 1.1219y_0 shape: [8 3]
# classes shape: [8 3]
#  199/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:21 4s/step - class_loss: 0.3640 - regress_loss: 0.9362 - total_loss: 1.1182y_0 shape: [8 3]
# classes shape: [8 3]
#  200/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:28 4s/step - class_loss: 0.3623 - regress_loss: 0.9327 - total_loss: 1.1139y_0 shape: [8 3]
# classes shape: [8 3]
#  201/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:46 4s/step - class_loss: 0.3609 - regress_loss: 0.9294 - total_loss: 1.1099y_0 shape: [8 3]
# classes shape: [8 3]
#  202/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:09 4s/step - class_loss: 0.3602 - regress_loss: 0.9294 - total_loss: 1.1095y_0 shape: [8 3]
# classes shape: [8 3]
#  203/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:35 4s/step - class_loss: 0.3590 - regress_loss: 0.9270 - total_loss: 1.1065y_0 shape: [8 3]
# classes shape: [8 3]
#  204/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:25 4s/step - class_loss: 0.3578 - regress_loss: 0.9253 - total_loss: 1.1042y_0 shape: [8 3]
# classes shape: [8 3]
#  205/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:21 4s/step - class_loss: 0.3562 - regress_loss: 0.9223 - total_loss: 1.1005y_0 shape: [8 3]
# classes shape: [8 3]
#  206/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:11 4s/step - class_loss: 0.3559 - regress_loss: 0.9211 - total_loss: 1.0991y_0 shape: [8 3]
# classes shape: [8 3]
#  207/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:59 4s/step - class_loss: 0.3548 - regress_loss: 0.9189 - total_loss: 1.0963y_0 shape: [8 3]
# classes shape: [8 3]
#  208/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:48 4s/step - class_loss: 0.3534 - regress_loss: 0.9169 - total_loss: 1.0936y_0 shape: [8 3]
# classes shape: [8 3]
#  209/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:40 4s/step - class_loss: 0.3521 - regress_loss: 0.9146 - total_loss: 1.0907y_0 shape: [8 3]
# classes shape: [8 3]
#  210/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:34 4s/step - class_loss: 0.3506 - regress_loss: 0.9113 - total_loss: 1.0866y_0 shape: [8 3]
# classes shape: [8 3]
#  211/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:23 4s/step - class_loss: 0.3508 - regress_loss: 0.9106 - total_loss: 1.0860y_0 shape: [8 3]
# classes shape: [8 3]
#  212/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:16 4s/step - class_loss: 0.3495 - regress_loss: 0.9072 - total_loss: 1.0819y_0 shape: [8 3]
# classes shape: [8 3]
#  213/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:07 4s/step - class_loss: 0.3478 - regress_loss: 0.9036 - total_loss: 1.0776y_0 shape: [8 3]
# classes shape: [8 3]
#  214/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:57 4s/step - class_loss: 0.3463 - regress_loss: 0.9004 - total_loss: 1.0735y_0 shape: [8 3]
# classes shape: [8 3]
#  215/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:47 4s/step - class_loss: 0.3465 - regress_loss: 0.9001 - total_loss: 1.0733y_0 shape: [8 3]
# classes shape: [8 3]
#  216/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:35 4s/step - class_loss: 0.3476 - regress_loss: 0.9056 - total_loss: 1.0793y_0 shape: [8 3]
# classes shape: [8 3]
#  217/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:27 4s/step - class_loss: 0.3502 - regress_loss: 0.9080 - total_loss: 1.0831y_0 shape: [8 3]
# classes shape: [8 3]
#  218/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:21 4s/step - class_loss: 0.3487 - regress_loss: 0.9053 - total_loss: 1.0797y_0 shape: [8 3]
# classes shape: [8 3]
#  219/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:22 4s/step - class_loss: 0.3472 - regress_loss: 0.9020 - total_loss: 1.0756y_0 shape: [8 3]
# classes shape: [8 3]
#  220/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:25 4s/step - class_loss: 0.3462 - regress_loss: 0.9050 - total_loss: 1.0781y_0 shape: [8 3]
# classes shape: [8 3]
#  221/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:23 4s/step - class_loss: 0.3454 - regress_loss: 0.9022 - total_loss: 1.0749y_0 shape: [8 3]
# classes shape: [8 3]
#  222/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:18 4s/step - class_loss: 0.3443 - regress_loss: 0.9006 - total_loss: 1.0728y_0 shape: [8 3]
# classes shape: [8 3]
#  223/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:11 4s/step - class_loss: 0.3429 - regress_loss: 0.8982 - total_loss: 1.0696y_0 shape: [8 3]
# classes shape: [8 3]
#  224/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:11 4s/step - class_loss: 0.3415 - regress_loss: 0.8964 - total_loss: 1.0671y_0 shape: [8 3]
# classes shape: [8 3]
#  225/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:10 4s/step - class_loss: 0.3413 - regress_loss: 0.8993 - total_loss: 1.0700y_0 shape: [8 3]
# classes shape: [8 3]
#  226/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:07 4s/step - class_loss: 0.3399 - regress_loss: 0.8966 - total_loss: 1.0665y_0 shape: [8 3]
# classes shape: [8 3]
#  227/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:04 4s/step - class_loss: 0.3385 - regress_loss: 0.8946 - total_loss: 1.0639y_0 shape: [8 3]
# classes shape: [8 3]
#  228/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:55 4s/step - class_loss: 0.3373 - regress_loss: 0.8926 - total_loss: 1.0613y_0 shape: [8 3]
# classes shape: [8 3]
#  229/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:54 4s/step - class_loss: 0.3359 - regress_loss: 0.8900 - total_loss: 1.0580y_0 shape: [8 3]
# classes shape: [8 3]
#  230/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:00 4s/step - class_loss: 0.3347 - regress_loss: 0.8873 - total_loss: 1.0547y_0 shape: [8 3]
# classes shape: [8 3]
#  231/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:17 4s/step - class_loss: 0.3335 - regress_loss: 0.8843 - total_loss: 1.0510y_0 shape: [8 3]
# classes shape: [8 3]
#  232/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:18 4s/step - class_loss: 0.3326 - regress_loss: 0.8817 - total_loss: 1.0480y_0 shape: [8 3]
# classes shape: [8 3]
#  233/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:49 4s/step - class_loss: 0.3313 - regress_loss: 0.8801 - total_loss: 1.0457y_0 shape: [8 3]
# classes shape: [8 3]
#  234/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:24 4s/step - class_loss: 0.3319 - regress_loss: 0.8785 - total_loss: 1.0445y_0 shape: [8 3]
# classes shape: [8 3]
#  235/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:47 4s/step - class_loss: 0.3321 - regress_loss: 0.8788 - total_loss: 1.0448y_0 shape: [8 3]
# classes shape: [8 3]
#  236/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:06 4s/step - class_loss: 0.3313 - regress_loss: 0.8761 - total_loss: 1.0418y_0 shape: [8 3]
# classes shape: [8 3]
#  237/1853 ━━━━━━━━━━━━━━━━━━━━ 1:50:02 4s/step - class_loss: 0.3302 - regress_loss: 0.8736 - total_loss: 1.0387y_0 shape: [8 3]
# classes shape: [8 3]
#  238/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:53 4s/step - class_loss: 0.3290 - regress_loss: 0.8720 - total_loss: 1.0365y_0 shape: [8 3]
# classes shape: [8 3]
#  239/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:44 4s/step - class_loss: 0.3276 - regress_loss: 0.8696 - total_loss: 1.0334y_0 shape: [8 3]
# classes shape: [8 3]
#  240/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:35 4s/step - class_loss: 0.3266 - regress_loss: 0.8671 - total_loss: 1.0304y_0 shape: [8 3]
# classes shape: [8 3]
#  241/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:26 4s/step - class_loss: 0.3253 - regress_loss: 0.8642 - total_loss: 1.0269y_0 shape: [8 3]
# classes shape: [8 3]
#  242/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:16 4s/step - class_loss: 0.3240 - regress_loss: 0.8618 - total_loss: 1.0238y_0 shape: [8 3]
# classes shape: [8 3]
#  243/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:07 4s/step - class_loss: 0.3248 - regress_loss: 0.8631 - total_loss: 1.0255y_0 shape: [8 3]
# classes shape: [8 3]
#  244/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:55 4s/step - class_loss: 0.3293 - regress_loss: 0.8747 - total_loss: 1.0394y_0 shape: [8 3]
# classes shape: [8 3]
#  245/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:46 4s/step - class_loss: 0.3281 - regress_loss: 0.8715 - total_loss: 1.0356y_0 shape: [8 3]
# classes shape: [8 3]
#  246/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:39 4s/step - class_loss: 0.3278 - regress_loss: 0.8705 - total_loss: 1.0344y_0 shape: [8 3]
# classes shape: [8 3]
#  247/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:41 4s/step - class_loss: 0.3269 - regress_loss: 0.8685 - total_loss: 1.0319y_0 shape: [8 3]
# classes shape: [8 3]
#  248/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:54 4s/step - class_loss: 0.3271 - regress_loss: 0.8670 - total_loss: 1.0306y_0 shape: [8 3]
# classes shape: [8 3]
#  249/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:10 4s/step - class_loss: 0.3269 - regress_loss: 0.8657 - total_loss: 1.0292y_0 shape: [8 3]
# classes shape: [8 3]
#  250/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:07 4s/step - class_loss: 0.3259 - regress_loss: 0.8634 - total_loss: 1.0263y_0 shape: [8 3]
# classes shape: [8 3]
#  251/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:14 4s/step - class_loss: 0.3260 - regress_loss: 0.8645 - total_loss: 1.0274y_0 shape: [8 3]
# classes shape: [8 3]
#  252/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:18 4s/step - class_loss: 0.3266 - regress_loss: 0.8641 - total_loss: 1.0274y_0 shape: [8 3]
# classes shape: [8 3]
#  253/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:15 4s/step - class_loss: 0.3276 - regress_loss: 0.8638 - total_loss: 1.0276y_0 shape: [8 3]
# classes shape: [8 3]
#  254/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:07 4s/step - class_loss: 0.3267 - regress_loss: 0.8613 - total_loss: 1.0247y_0 shape: [8 3]
# classes shape: [8 3]
#  255/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:02 4s/step - class_loss: 0.3255 - regress_loss: 0.8588 - total_loss: 1.0216y_0 shape: [8 3]
# classes shape: [8 3]
#  256/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:56 4s/step - class_loss: 0.3251 - regress_loss: 0.8585 - total_loss: 1.0211y_0 shape: [8 3]
# classes shape: [8 3]
#  257/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:52 4s/step - class_loss: 0.3248 - regress_loss: 0.8575 - total_loss: 1.0199y_0 shape: [8 3]
# classes shape: [8 3]
#  258/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:46 4s/step - class_loss: 0.3246 - regress_loss: 0.8583 - total_loss: 1.0206y_0 shape: [8 3]
# classes shape: [8 3]
#  259/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:37 4s/step - class_loss: 0.3248 - regress_loss: 0.8564 - total_loss: 1.0188y_0 shape: [8 3]
# classes shape: [8 3]
#  260/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:32 4s/step - class_loss: 0.3266 - regress_loss: 0.8547 - total_loss: 1.0180y_0 shape: [8 3]
# classes shape: [8 3]
#  261/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:23 4s/step - class_loss: 0.3261 - regress_loss: 0.8557 - total_loss: 1.0188y_0 shape: [8 3]
# classes shape: [8 3]
#  262/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:13 4s/step - class_loss: 0.3262 - regress_loss: 0.8569 - total_loss: 1.0200y_0 shape: [8 3]
# classes shape: [8 3]
#  263/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:04 4s/step - class_loss: 0.3258 - regress_loss: 0.8570 - total_loss: 1.0199y_0 shape: [8 3]
# classes shape: [8 3]
#  264/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:54 4s/step - class_loss: 0.3246 - regress_loss: 0.8548 - total_loss: 1.0171y_0 shape: [8 3]
# classes shape: [8 3]
#  265/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:56 4s/step - class_loss: 0.3248 - regress_loss: 0.8574 - total_loss: 1.0198y_0 shape: [8 3]
# classes shape: [8 3]
#  266/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:11 4s/step - class_loss: 0.3237 - regress_loss: 0.8557 - total_loss: 1.0176y_0 shape: [8 3]
# classes shape: [8 3]
#  267/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:10 4s/step - class_loss: 0.3228 - regress_loss: 0.8534 - total_loss: 1.0148y_0 shape: [8 3]
# classes shape: [8 3]
#  268/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:05 4s/step - class_loss: 0.3222 - regress_loss: 0.8507 - total_loss: 1.0118y_0 shape: [8 3]
# classes shape: [8 3]
#  269/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:18 4s/step - class_loss: 0.3216 - regress_loss: 0.8492 - total_loss: 1.0099y_0 shape: [8 3]
# classes shape: [8 3]
#  270/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:20 4s/step - class_loss: 0.3219 - regress_loss: 0.8541 - total_loss: 1.0151y_0 shape: [8 3]
# classes shape: [8 3]
#  271/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:21 4s/step - class_loss: 0.3209 - regress_loss: 0.8520 - total_loss: 1.0125y_0 shape: [8 3]
# classes shape: [8 3]
#  272/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:20 4s/step - class_loss: 0.3198 - regress_loss: 0.8507 - total_loss: 1.0106y_0 shape: [8 3]
# classes shape: [8 3]
#  273/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:15 4s/step - class_loss: 0.3187 - regress_loss: 0.8483 - total_loss: 1.0076y_0 shape: [8 3]
# classes shape: [8 3]
#  274/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:13 4s/step - class_loss: 0.3179 - regress_loss: 0.8488 - total_loss: 1.0078y_0 shape: [8 3]
# classes shape: [8 3]
#  275/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:09 4s/step - class_loss: 0.3170 - regress_loss: 0.8469 - total_loss: 1.0054y_0 shape: [8 3]
# classes shape: [8 3]
#  276/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:04 4s/step - class_loss: 0.3170 - regress_loss: 0.8478 - total_loss: 1.0063y_0 shape: [8 3]
# classes shape: [8 3]
#  277/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:03 4s/step - class_loss: 0.3162 - regress_loss: 0.8453 - total_loss: 1.0033y_0 shape: [8 3]
# classes shape: [8 3]
#  278/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:03 4s/step - class_loss: 0.3153 - regress_loss: 0.8432 - total_loss: 1.0008y_0 shape: [8 3]
# classes shape: [8 3]
#  279/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:14 4s/step - class_loss: 0.3149 - regress_loss: 0.8438 - total_loss: 1.0012y_0 shape: [8 3]
# classes shape: [8 3]
#  280/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:18 4s/step - class_loss: 0.3154 - regress_loss: 0.8442 - total_loss: 1.0019y_0 shape: [8 3]
# classes shape: [8 3]
#  281/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:16 4s/step - class_loss: 0.3145 - regress_loss: 0.8421 - total_loss: 0.9994y_0 shape: [8 3]
# classes shape: [8 3]
#  282/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:14 4s/step - class_loss: 0.3139 - regress_loss: 0.8426 - total_loss: 0.9996y_0 shape: [8 3]
# classes shape: [8 3]
#  283/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:08 4s/step - class_loss: 0.3132 - regress_loss: 0.8416 - total_loss: 0.9981y_0 shape: [8 3]
# classes shape: [8 3]
#  284/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:03 4s/step - class_loss: 0.3128 - regress_loss: 0.8410 - total_loss: 0.9975y_0 shape: [8 3]
# classes shape: [8 3]
#  285/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:03 4s/step - class_loss: 0.3126 - regress_loss: 0.8388 - total_loss: 0.9951y_0 shape: [8 3]
# classes shape: [8 3]
#  286/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:04 4s/step - class_loss: 0.3126 - regress_loss: 0.8385 - total_loss: 0.9948y_0 shape: [8 3]
# classes shape: [8 3]
#  287/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:01 4s/step - class_loss: 0.3117 - regress_loss: 0.8367 - total_loss: 0.9926y_0 shape: [8 3]
# classes shape: [8 3]
#  288/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:56 4s/step - class_loss: 0.3117 - regress_loss: 0.8388 - total_loss: 0.9947y_0 shape: [8 3]
# classes shape: [8 3]
#  289/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:49 4s/step - class_loss: 0.3117 - regress_loss: 0.8386 - total_loss: 0.9945y_0 shape: [8 3]
# classes shape: [8 3]
#  290/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:49 4s/step - class_loss: 0.3112 - regress_loss: 0.8376 - total_loss: 0.9932y_0 shape: [8 3]
# classes shape: [8 3]
#  291/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:42 4s/step - class_loss: 0.3108 - regress_loss: 0.8370 - total_loss: 0.9924y_0 shape: [8 3]
# classes shape: [8 3]
#  292/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:40 4s/step - class_loss: 0.3101 - regress_loss: 0.8365 - total_loss: 0.9916y_0 shape: [8 3]
# classes shape: [8 3]
#  293/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:37 4s/step - class_loss: 0.3107 - regress_loss: 0.8381 - total_loss: 0.9935y_0 shape: [8 3]
# classes shape: [8 3]
#  294/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:36 4s/step - class_loss: 0.3100 - regress_loss: 0.8366 - total_loss: 0.9916y_0 shape: [8 3]
# classes shape: [8 3]
#  295/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:44 4s/step - class_loss: 0.3102 - regress_loss: 0.8382 - total_loss: 0.9933y_0 shape: [8 3]
# classes shape: [8 3]
#  296/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:46 4s/step - class_loss: 0.3093 - regress_loss: 0.8372 - total_loss: 0.9918y_0 shape: [8 3]
# classes shape: [8 3]
#  297/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:47 4s/step - class_loss: 0.3087 - regress_loss: 0.8359 - total_loss: 0.9903y_0 shape: [8 3]
# classes shape: [8 3]
#  298/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:43 4s/step - class_loss: 0.3080 - regress_loss: 0.8346 - total_loss: 0.9886y_0 shape: [8 3]
# classes shape: [8 3]
#  299/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:38 4s/step - class_loss: 0.3077 - regress_loss: 0.8347 - total_loss: 0.9886y_0 shape: [8 3]
# classes shape: [8 3]
#  300/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:36 4s/step - class_loss: 0.3076 - regress_loss: 0.8329 - total_loss: 0.9867y_0 shape: [8 3]
# classes shape: [8 3]
#  301/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:31 4s/step - class_loss: 0.3072 - regress_loss: 0.8358 - total_loss: 0.9894y_0 shape: [8 3]
# classes shape: [8 3]
#  302/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:25 4s/step - class_loss: 0.3062 - regress_loss: 0.8335 - total_loss: 0.9866y_0 shape: [8 3]
# classes shape: [8 3]
#  303/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:33 4s/step - class_loss: 0.3053 - regress_loss: 0.8313 - total_loss: 0.9840y_0 shape: [8 3]
# classes shape: [8 3]
#  304/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:49 4s/step - class_loss: 0.3045 - regress_loss: 0.8295 - total_loss: 0.9817y_0 shape: [8 3]
# classes shape: [8 3]
#  305/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:55 4s/step - class_loss: 0.3045 - regress_loss: 0.8290 - total_loss: 0.9812y_0 shape: [8 3]
# classes shape: [8 3]
#  306/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:50 4s/step - class_loss: 0.3038 - regress_loss: 0.8281 - total_loss: 0.9800y_0 shape: [8 3]
# classes shape: [8 3]
#  307/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:44 4s/step - class_loss: 0.3030 - regress_loss: 0.8271 - total_loss: 0.9786y_0 shape: [8 3]
# classes shape: [8 3]
#  308/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:38 4s/step - class_loss: 0.3021 - regress_loss: 0.8250 - total_loss: 0.9761y_0 shape: [8 3]
# classes shape: [8 3]
#  309/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:32 4s/step - class_loss: 0.3012 - regress_loss: 0.8232 - total_loss: 0.9738y_0 shape: [8 3]
# classes shape: [8 3]
#  310/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:28 4s/step - class_loss: 0.3008 - regress_loss: 0.8240 - total_loss: 0.9744y_0 shape: [8 3]
# classes shape: [8 3]
#  311/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:23 4s/step - class_loss: 0.3000 - regress_loss: 0.8220 - total_loss: 0.9720y_0 shape: [8 3]
# classes shape: [8 3]
#  312/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:17 4s/step - class_loss: 0.2992 - regress_loss: 0.8201 - total_loss: 0.9697y_0 shape: [8 3]
# classes shape: [8 3]
#  313/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:16 4s/step - class_loss: 0.2989 - regress_loss: 0.8220 - total_loss: 0.9715y_0 shape: [8 3]
# classes shape: [8 3]
# ...
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# y_0 shape: [8 3]
# classes shape: [8 3]
# 1853/1853 ━━━━━━━━━━━━━━━━━━━━ 7550s 4s/step - class_loss: 0.1615 - regress_loss: 0.4758 - total_loss: 0.5566 - val_class_loss: 1.9226 - val_regress_loss: 2.2034 - val_total_loss: 3.1647
# Epoch 2/10
# 2024-05-26 15:15:46.028897: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 3490 of 15000
# 2024-05-26 15:16:06.017990: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:26: Filling up shuffle buffer (this may take a while): 10220 of 15000
# y_0 shape: [8 3]
# 2024-05-26 15:16:21.278940: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# classes shape: [8 3]
#    1/1853 ━━━━━━━━━━━━━━━━━━━━ 26:00:17 51s/step - class_loss: 0.0294 - regress_loss: 0.0613 - total_loss: 0.0760y_0 shape: [8 3]
# classes shape: [8 3]
#    2/1853 ━━━━━━━━━━━━━━━━━━━━ 2:04:05 4s/step - class_loss: 0.0263 - regress_loss: 0.0710 - total_loss: 0.0842  y_0 shape: [8 3]
# classes shape: [8 3]
#    3/1853 ━━━━━━━━━━━━━━━━━━━━ 1:58:55 4s/step - class_loss: 0.0248 - regress_loss: 0.0878 - total_loss: 0.1002y_0 shape: [8 3]
# classes shape: [8 3]
#    4/1853 ━━━━━━━━━━━━━━━━━━━━ 1:56:12 4s/step - class_loss: 0.0862 - regress_loss: 0.3799 - total_loss: 0.4230y_0 shape: [8 3]
# classes shape: [8 3]
#    5/1853 ━━━━━━━━━━━━━━━━━━━━ 1:54:06 4s/step - class_loss: 0.0730 - regress_loss: 0.3233 - total_loss: 0.3598y_0 shape: [8 3]
# classes shape: [8 3]
#    6/1853 ━━━━━━━━━━━━━━━━━━━━ 1:51:47 4s/step - class_loss: 0.0614 - regress_loss: 0.2809 - total_loss: 0.3116y_0 shape: [8 3]
# classes shape: [8 3]
#    7/1853 ━━━━━━━━━━━━━━━━━━━━ 1:49:54 4s/step - class_loss: 0.0536 - regress_loss: 0.2528 - total_loss: 0.2796y_0 shape: [8 3]
# classes shape: [8 3]
#    8/1853 ━━━━━━━━━━━━━━━━━━━━ 1:48:16 4s/step - class_loss: 0.1002 - regress_loss: 0.3442 - total_loss: 0.3943y_0 shape: [8 3]
# classes shape: [8 3]
#    9/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:15 3s/step - class_loss: 0.1409 - regress_loss: 0.4598 - total_loss: 0.5303y_0 shape: [8 3]
# classes shape: [8 3]
#   10/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:38 3s/step - class_loss: 0.1278 - regress_loss: 0.4181 - total_loss: 0.4820y_0 shape: [8 3]
# classes shape: [8 3]
#   11/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:38 3s/step - class_loss: 0.1177 - regress_loss: 0.3855 - total_loss: 0.4443y_0 shape: [8 3]
# classes shape: [8 3]
#   12/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:21 3s/step - class_loss: 0.1110 - regress_loss: 0.3610 - total_loss: 0.4165y_0 shape: [8 3]
# classes shape: [8 3]
#   13/1853 ━━━━━━━━━━━━━━━━━━━━ 1:47:02 3s/step - class_loss: 0.1070 - regress_loss: 0.3506 - total_loss: 0.4041y_0 shape: [8 3]
# classes shape: [8 3]
#   14/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:52 3s/step - class_loss: 0.1031 - regress_loss: 0.3392 - total_loss: 0.3907y_0 shape: [8 3]
# classes shape: [8 3]
#   15/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:45 3s/step - class_loss: 0.1185 - regress_loss: 0.3860 - total_loss: 0.4452y_0 shape: [8 3]
# classes shape: [8 3]
#   16/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:17 3s/step - class_loss: 0.1153 - regress_loss: 0.3762 - total_loss: 0.4338y_0 shape: [8 3]
# classes shape: [8 3]
#   17/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:11 3s/step - class_loss: 0.1088 - regress_loss: 0.3587 - total_loss: 0.4131y_0 shape: [8 3]
# classes shape: [8 3]
#   18/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:05 3s/step - class_loss: 0.1043 - regress_loss: 0.3435 - total_loss: 0.3957y_0 shape: [8 3]
# classes shape: [8 3]
#   19/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:43 3s/step - class_loss: 0.0989 - regress_loss: 0.3281 - total_loss: 0.3775y_0 shape: [8 3]
# classes shape: [8 3]
#   20/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:45 3s/step - class_loss: 0.0951 - regress_loss: 0.3134 - total_loss: 0.3610y_0 shape: [8 3]
# classes shape: [8 3]
#   21/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:40 3s/step - class_loss: 0.0947 - regress_loss: 0.3148 - total_loss: 0.3621y_0 shape: [8 3]
# classes shape: [8 3]
#   22/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:14 3s/step - class_loss: 0.0907 - regress_loss: 0.3034 - total_loss: 0.3488y_0 shape: [8 3]
# classes shape: [8 3]
#   23/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:57 3s/step - class_loss: 0.0991 - regress_loss: 0.3510 - total_loss: 0.4006y_0 shape: [8 3]
# classes shape: [8 3]
#   24/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:03 3s/step - class_loss: 0.0957 - regress_loss: 0.3385 - total_loss: 0.3864y_0 shape: [8 3]
# classes shape: [8 3]
#   25/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:05 3s/step - class_loss: 0.0921 - regress_loss: 0.3293 - total_loss: 0.3754y_0 shape: [8 3]
# classes shape: [8 3]
#   26/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:36 4s/step - class_loss: 0.0901 - regress_loss: 0.3211 - total_loss: 0.3661y_0 shape: [8 3]
# classes shape: [8 3]
#   27/1853 ━━━━━━━━━━━━━━━━━━━━ 1:46:21 3s/step - class_loss: 0.0875 - regress_loss: 0.3108 - total_loss: 0.3546y_0 shape: [8 3]
# classes shape: [8 3]
#   28/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:56 3s/step - class_loss: 0.0961 - regress_loss: 0.3115 - total_loss: 0.3596y_0 shape: [8 3]
# classes shape: [8 3]
#   29/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:39 3s/step - class_loss: 0.0999 - regress_loss: 0.3162 - total_loss: 0.3661y_0 shape: [8 3]
# classes shape: [8 3]
#   30/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:22 3s/step - class_loss: 0.0969 - regress_loss: 0.3093 - total_loss: 0.3578y_0 shape: [8 3]
# classes shape: [8 3]
#   31/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:09 3s/step - class_loss: 0.0964 - regress_loss: 0.3070 - total_loss: 0.3552y_0 shape: [8 3]
# classes shape: [8 3]
#   32/1853 ━━━━━━━━━━━━━━━━━━━━ 1:45:02 3s/step - class_loss: 0.0944 - regress_loss: 0.3029 - total_loss: 0.3501y_0 shape: [8 3]
# classes shape: [8 3]
#   33/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:50 3s/step - class_loss: 0.0916 - regress_loss: 0.2973 - total_loss: 0.3430y_0 shape: [8 3]
# classes shape: [8 3]
#   34/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:36 3s/step - class_loss: 0.0892 - regress_loss: 0.2907 - total_loss: 0.3354y_0 shape: [8 3]
# classes shape: [8 3]
#   35/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:27 3s/step - class_loss: 0.0935 - regress_loss: 0.2958 - total_loss: 0.3426y_0 shape: [8 3]
# classes shape: [8 3]
#   36/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:40 3s/step - class_loss: 0.0936 - regress_loss: 0.3021 - total_loss: 0.3489y_0 shape: [8 3]
# classes shape: [8 3]
#   37/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:34 3s/step - class_loss: 0.0915 - regress_loss: 0.2962 - total_loss: 0.3419y_0 shape: [8 3]
# classes shape: [8 3]
#   38/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:18 3s/step - class_loss: 0.0897 - regress_loss: 0.2906 - total_loss: 0.3355y_0 shape: [8 3]
# classes shape: [8 3]
#   39/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:09 3s/step - class_loss: 0.0882 - regress_loss: 0.2876 - total_loss: 0.3317y_0 shape: [8 3]
# classes shape: [8 3]
#   40/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:19 3s/step - class_loss: 0.0941 - regress_loss: 0.2928 - total_loss: 0.3398y_0 shape: [8 3]
# classes shape: [8 3]
#   41/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:13 3s/step - class_loss: 0.0920 - regress_loss: 0.2886 - total_loss: 0.3346y_0 shape: [8 3]
# classes shape: [8 3]
#   42/1853 ━━━━━━━━━━━━━━━━━━━━ 1:44:03 3s/step - class_loss: 0.0900 - regress_loss: 0.2847 - total_loss: 0.3296y_0 shape: [8 3]
# classes shape: [8 3]
#   43/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:51 3s/step - class_loss: 0.0902 - regress_loss: 0.2843 - total_loss: 0.3294y_0 shape: [8 3]
# classes shape: [8 3]
#   44/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:42 3s/step - class_loss: 0.0939 - regress_loss: 0.2983 - total_loss: 0.3452y_0 shape: [8 3]
# classes shape: [8 3]
#   45/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:29 3s/step - class_loss: 0.0922 - regress_loss: 0.2925 - total_loss: 0.3387y_0 shape: [8 3]
# classes shape: [8 3]
#   46/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:16 3s/step - class_loss: 0.0905 - regress_loss: 0.2871 - total_loss: 0.3323y_0 shape: [8 3]
# classes shape: [8 3]
#   47/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:03 3s/step - class_loss: 0.0893 - regress_loss: 0.2831 - total_loss: 0.3277y_0 shape: [8 3]
# classes shape: [8 3]
#   48/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:08 3s/step - class_loss: 0.0878 - regress_loss: 0.2793 - total_loss: 0.3232y_0 shape: [8 3]
# classes shape: [8 3]
#   49/1853 ━━━━━━━━━━━━━━━━━━━━ 1:43:11 3s/step - class_loss: 0.0902 - regress_loss: 0.3024 - total_loss: 0.3474y_0 shape: [8 3]
# classes shape: [8 3]
#   50/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:58 3s/step - class_loss: 0.0884 - regress_loss: 0.3014 - total_loss: 0.3456y_0 shape: [8 3]
# classes shape: [8 3]
#   51/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:50 3s/step - class_loss: 0.0894 - regress_loss: 0.3172 - total_loss: 0.3619y_0 shape: [8 3]
# classes shape: [8 3]
#   52/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:42 3s/step - class_loss: 0.0892 - regress_loss: 0.3133 - total_loss: 0.3579y_0 shape: [8 3]
# classes shape: [8 3]
#   53/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:34 3s/step - class_loss: 0.0885 - regress_loss: 0.3088 - total_loss: 0.3531y_0 shape: [8 3]
# classes shape: [8 3]
#   54/1853 ━━━━━━━━━━━━━━━━━━━━ 1:42:26 3s/step - class_loss: 0.0895 - regress_loss: 0.3281 - total_loss: 0.3729

# %%
hist.history # wyświetl historię metryk(błędów), jeśli maleją, to jest okej

# %% [markdown]
# # 10.3 Plot Performance

# %%
# wyswietl historie bledow na wykresach
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='total loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val total loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

# %% [markdown]
# # 11. Make Predictions

# %%
facetracker = load_model('facetracker.h5') # wczytaj model z pliku
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample = test_data.next()

# %%
yhat = facetracker.predict(test_sample[0]) # zgadnij gdzie jest ramka
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %% [markdown]
# ## 11.1 Make Predictions on Test Set

# %%
fif, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4):
    sample_image = test_sample[0][idx]
    sample_coords = yhat[1][idx]

    # Normalizacja obrazu, zeby umozliwic wyswietlenie
    normalized_image_np = cv2.normalize(sample_image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    sample_image_umat = cv2.UMat(normalized_image_np) 

    # Wywołanie funkcji cv2.rectangle na obiekcie UMat
    if yhat[0][idx] > 0.5:
        cv2.rectangle(sample_image_umat,
                      tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)),
                      (255,0,0),2)

    # Wyświetlenie znormalizowanego obrazu
    ax[idx].imshow(sample_image_umat.get())

# %% [markdown]
# ## 11.2 Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
facetracker.save('facetracker.h5') #zapisz model w pliku facetracker.h5
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
facetracker = load_model('facetracker.h5') # wczytaj model z pliku
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## 11.3 Real Time Detection  FINAL!!!!

# %%
# cap = cv2.VideoCapture(0) # 0 lub 1, tak jak na początku przy robieniu zdjęć
# while cap.isOpened():
#     _ , frame = cap.read()
#     frame = frame[50:500, 50:500, :]

#     rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     resized= tf.image.resize(rgb, (120,120))

#     yhat = facetracker.predict(np.expand_dims(resized/255,0))
#     sample_coords = yhat[1][0]

#     # Wyświetl
#     # jesli tutaj pojawia sie blad, mozliwe, ze trzeba znowrmalizowac, jak 4 okienka powyzej
#     if yhat[0] > 0.5:
#         # wyświtlenie głównego prostokąta?
#         cv2.rectangle(frame,tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)),(255,0,0),2)
#         # wyświetlenie ramki
#         cv2.rectangle(frame,tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),[0,-30])),tuple(np.add(np.multiply(sample_coords[2:], [450,450]).astype(int),[80,0])),(255,0,0), 2)
#         # wyświetlenie tekstu
#         cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),[0,5])),cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

#     cv2.imshow('EyeTrack', frame)

#     if cv2.waitKey(1) & 0xFF ==ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0) # 0 lub 1, tak jak na początku przy robieniu zdjęć
while cap.isOpened():
    _, frame = cap.read()
    frame = frame[50:500, 50:500, :]

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120, 120))

    # tutaj oprocz ramki jeszcze klasyfikacja z osobą
    classes, coords = facetracker.predict(np.expand_dims(resized / 255, 0))
    sample_coords = coords[0]

    # Jeżeli wykryto twarz to przypisz odpowiednią etykietę
    if classes[0] > 0.5:
        if classes[0] == 1:
            label = 'Asia'
        elif classes[0] == 2:
            label = 'Ola'
        else:
            label = 'unknown'
        
        # Wyświetlenia z odpowiednią etykietą
        cv2.rectangle(frame, tuple(np.multiply(sample_coords[:2], [450, 450]).astype(int)), tuple(np.multiply(sample_coords[2:], [450, 450]).astype(int)), (255, 0, 0), 2)
        cv2.rectangle(frame, tuple(np.add(np.multiply(sample_coords[:2], [450, 450]).astype(int), [0, -30])), tuple(np.add(np.multiply(sample_coords[2:], [450, 450]).astype(int), [80, 0])), (255, 0, 0), 2)
        cv2.putText(frame, label, tuple(np.add(np.multiply(sample_coords[:2], [450, 450]).astype(int), [0, 5])), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    cv2.imshow('EyeTrack', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 14
#      11 sample_coords = coords[0]
#      13 # Jeżeli wykryto twarz to przypisz odpowiednią etykietę
# ---> 14 if classes[0] > 0.5:
#      15     if classes[0] == 1:
#      16         label = 'Asia'
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
cap = cv2.VideoCapture(0)  # 0 or 1, as in the beginning when taking pictures
while cap.isOpened():
    _, frame = cap.read()
    frame = frame[50:500, 50:500, :]

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120, 120))

    # Perform prediction
    classes, coords = facetracker.predict(np.expand_dims(resized / 255, 0))
    sample_coords = coords[0]

    # Assuming classes is a one-hot encoded array
    class_idx = np.argmax(classes[0])
    confidence = classes[0][class_idx]
    print(classes[0][2])
    # If a face is detected with confidence above 0.5, assign the corresponding label
    if confidence > 0.5:
        if class_idx == 1 and classes[0][1] >0.9 and classes[0][1]>classes[0][2]:
            label = 'Asia'
        elif class_idx == 2 and classes[0][2] >0.9 and classes[0][1]<classes[0][2]:
            label = 'Ola'
        else:
            label = 'unknown'

        # Display with the corresponding label
        cv2.rectangle(frame, tuple(np.multiply(sample_coords[:2], [450, 450]).astype(int)), 
                      tuple(np.multiply(sample_coords[2:], [450, 450]).astype(int)), (255, 0, 0), 2)
        cv2.rectangle(frame, tuple(np.add(np.multiply(sample_coords[:2], [450, 450]).astype(int), [0, -30])), 
                      tuple(np.add(np.multiply(sample_coords[2:], [450, 450]).astype(int), [80, 0])), (255, 0, 0), 2)
        cv2.putText(frame, label, tuple(np.add(np.multiply(sample_coords[:2], [450, 450]).astype(int), [0, 5])), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    cv2.imshow('EyeTrack', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.00040647067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.040356684
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.429189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.9954526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.34919202
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.81316376
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.9844722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.9985428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9997286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.99940395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9993886
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99889565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.99926287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99919564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.99942625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9995378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.9994394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.99977046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9998933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99977595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.99960285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9990639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 0.9953975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.98451716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9873849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9969035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.9981336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99908066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.9977639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.999711
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9999578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9999676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.999979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99996626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9999728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9961499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9982304
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99407107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9536518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.6225074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.16205135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.23948084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.35324177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.23689838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.85872835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99305266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99823904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 0.9996706
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99978477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9996542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9997397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9997857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99957854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.998904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.99986386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9982413
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9924516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9821878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9837323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9873679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 0.9861102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9976864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99735105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9937032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.99707294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99706095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9998149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9999269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99995315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9999527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.99985516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99979013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9999747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9999621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.9999703
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99995637
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99993134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99991965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9999316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99996114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99996567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 0.9999567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9999682
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9999155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9998405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9996884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9995345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9997732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99969697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.9997898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.999801
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99978346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99983394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.9997894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9996871
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99970526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99956924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.999508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.999887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99928635
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9978411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 0.99265176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99847966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9994815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9997626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9996853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9997936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9999045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99991214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99993396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99994683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.999949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 0.99988544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99987936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9999125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99990666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9999095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99990463
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9998939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99989784
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9999057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99993396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99994385
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9999356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.9999269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.9999157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99995184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9999385
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9999405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 0.99995935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9999708
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9999491
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.999956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99996746
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9999387
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99990654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99991107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99952984
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.999671
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9998161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99984694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9998909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9998223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9997745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99984384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99990726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.99992275
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9999232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.9998455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9999641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99996305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99988484
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9998952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9997565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9996505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99956185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99955577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9996024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.3851483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.22787409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.30625394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.52723294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.609333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.12140949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9393709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.32259417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.37247878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.07335951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.0020810554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.0005524768
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.00071541197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.00093640795
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.03140159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 6.9725895e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.0001968407
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.004559302
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.00056634046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 0.0008467554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0022356985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.024275258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.048015617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 0.059379786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.039792825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.09371875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.14952496
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.22228487
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.37048113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.4966513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.38843012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.33050454
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.43150747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.22383533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 0.8339324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.7869882
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.88379383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.7938551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.8524736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.7313267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.7615976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.81312835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.7448489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.7488302
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.77852386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.8043075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.68829614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.77699333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.7948942
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.73714066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.7548794
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.74107945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.71280473
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.7031703
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 0.64733624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.8107156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.6899919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.76997066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.73225445
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.7161089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.69048375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.63609886
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.78296787
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.8120743
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.7756306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.7532234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.7435043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.7419069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.6557501
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.697493
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.7684553
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.48825547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.738919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.73735654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.5444758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.76572
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.8123599
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0.8077398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.7094541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.72098184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.7870523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.7364077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.7167414
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.6953702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.7834698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.8115889
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.91337264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.24719384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.12351315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.053091995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.12740992
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.8021698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9155934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.6326462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.63214445
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.77805364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.688718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.694844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.5056908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.01073941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.0007732203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.030009823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.69258636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.65333724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.80713874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.4702114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.88782716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.7589941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.6292537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.8580094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.3424511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.5713844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.58372307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 0.481111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.013899863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.05249443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.43612424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.3357913
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.77667105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 8.8661094e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4.568263e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 0.8254962
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.19348395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.010323278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.021278279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.03810049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.111937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.2551771
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.051060274
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 0.04448748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 3.7922804e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.0003438276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.067623325
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9169582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9859093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9941559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9963819
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.997299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9990188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99925965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99866366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9982905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.99865663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9988539
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 0.9988017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99859554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99544877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99691856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9996753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9994123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.9994991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 0.9991068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9992699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99918586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9989611
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.999238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9994659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9995078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 0.99918646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9992155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.999356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.99913675
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99909353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9988919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9987203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99947053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99949825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99941564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9997949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99990857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9998683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 0.96179295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.20075642
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9094181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.999571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9997559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9983986
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99364024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 0.9997639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.982301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9948372
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9987778
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99987113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9995999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9976199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 0.9976641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9922626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9999355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.85697925
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.019662103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.11135549
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 0.27043873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.09196138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.07048096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.560044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.5305615
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.1690286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 0.5187467
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.58857304
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.29643595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.17949401
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.8585046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99925536
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 0.9993098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99897885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99880016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99802005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99802005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9948921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.9975382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.9887261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.677378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.77293915
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.08925486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.16128173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.98825526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 0.88696694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9975821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9909711
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9085066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9552146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.98294306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9907488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.99764985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99995613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9998247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9998871
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.99569464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.98348755
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.41081423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.061133154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.36482954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.22711086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99512744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.8258577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 0.13399062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.85425
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9942878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.97419864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.97997963
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9979182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9958411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.99074626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99455726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.99569786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.99834967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.99838495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9991443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 0.9992669
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.99553216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99716645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9985655
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99683064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.98978233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9965161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9990176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9927046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99611735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.99276125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99113876
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.960276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.7826562
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 0.20172338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.0022149628
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.00594923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0020623687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.0035988102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.66087145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 0.11893478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 0.31084993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0014142728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0016526195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0010702647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.002122666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0016542794
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.0013902446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 0.0013752542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0012314979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0014700593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0009151737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0008587797
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0009600537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0009325839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.0009982634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 0.001003149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.0009373858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0009965716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0010779509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0011709277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 0.0012073636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0012487477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.0012801912
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0013157434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0015633842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.0019740856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0015695061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 0.0014531416
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0020815965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.001929166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.0024617515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0024186063
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.002128938
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 0.0021985495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.0015804581
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.0016032223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0016022531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.0020172969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0016454105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0014385057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 0.001569167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.0021920812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0019190358
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.003766438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.0023845138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0022235054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0031261912
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 0.0023458137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.0024818056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0044799573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0028705252
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0026627914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.0035552403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.0035901177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0025418745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.0038230396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0033553825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.0024961904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.0032927503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.00301879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.0037149282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.010806529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.0068314937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.009852366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.21245028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.13696967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.11811248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.98473626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.97260123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9832987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.9756738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.98218715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.8356311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.80103105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.9624391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.9725779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 0.9760557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9937541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9910431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9952384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9929442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9932573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9728505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.9428346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.9699877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.99694854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9923747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.87015533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.98396516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9929448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.98031276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.97572494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 0.9846652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9929103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.99074215
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.93812054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9155532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9188969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 0.6330329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.49044254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 0.6280646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.94192755
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.99395305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99140817
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.9963123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99418867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.9702345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.66317093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.05843822
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.06627699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.024115602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.049732458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.3675874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9397007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 0.81027377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9927181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9909185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.86723524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.89142644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.8933807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 0.9239343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9437295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9037255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.83287716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.61571854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.51285243
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.54876417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.5444009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.58932865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.50645095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.60874116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.49472404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.37349093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.5320026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.38620538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.47802928
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 0.38092855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.5859924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.6261961
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.5902792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.71339595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.60932636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.5536082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 0.6042503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 0.5976483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.6404687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.6068867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.62794626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.6117705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 0.69198674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 0.68363756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.69868106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.6201632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.601011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.5718838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.53722924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.5353256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.65578175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.65313774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 0.61790913
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.6714809
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.71204317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.7200152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.6080375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.6516837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.6052933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 0.74550337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.6308109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.6488079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.5351392
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.6559933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.7327748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.7515826
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 0.60511273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.68860096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 0.724305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.5975018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.64734036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.8599956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.30311605
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 0.054447874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.024401767
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.15850493
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.09700853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.021006826
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 0.13330634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.13432737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 0.10306133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.01568732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.0027968816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.0023386271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.00016026225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1.2367515e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.0012796165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 0.022807097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.01039377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.009909568
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.0024962265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 3.322622e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2.7171984e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1.1009614e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 0.9911963
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 0.99229735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 0.9994254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 0.9994429
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.99919504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.9995332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9997855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.9998603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0.99988246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9999629
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 0.99996865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.99888426
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9948402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.9981316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.9969874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 0.9957866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.9977144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.9987062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.9946827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 0.96342003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.47647175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 0.27027455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.1673029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 0.91109544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.87824386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 0.972386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 0.99284995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.99975973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 0.9997218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 0.999925
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 0.9999001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
